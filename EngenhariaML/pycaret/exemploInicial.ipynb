# %%
import pandas as pd 

dataset = pd.read_csv('titanic.csv', sep=',', decimal='.')

filtrado = (
    dataset[['Survived', 'Pclass', 'Age', 'SibSp', 'Parch', 'Fare']]
        .join(pd.get_dummies(dataset['Embarked'], prefix='Embarked'))
        .join(pd.get_dummies(dataset['Sex'], prefix='Sex'))
        .dropna()
        .assign(Survived=lambda x: x['Survived'].astype(bool))
)

filtrado
# Out:
#      Survived  Pclass   Age  SibSp  Parch     Fare  Embarked_C  Embarked_Q  \
# 0       False       3  22.0      1      0   7.2500       False       False
# 1        True       1  38.0      1      0  71.2833        True       False
# 2        True       3  26.0      0      0   7.9250       False       False
# 3        True       1  35.0      1      0  53.1000       False       False
# 4       False       3  35.0      0      0   8.0500       False       False
# ..        ...     ...   ...    ...    ...      ...         ...         ...
# 885     False       3  39.0      0      5  29.1250       False        True
# 886     False       2  27.0      0      0  13.0000       False       False
# 887      True       1  19.0      0      0  30.0000       False       False
# 889      True       1  26.0      0      0  30.0000        True       False
# 890     False       3  32.0      0      0   7.7500       False        True
#
#      Embarked_S  Sex_female  Sex_male
# 0          True       False      True
# 1         False        True     False
# 2          True        True     False
# 3          True        True     False
# 4          True       False      True
# ..          ...         ...       ...
# 885       False        True     False
# 886        True       False      True
# 887        True        True     False
# 889       False       False      True
# 890       False       False      True
#
# [714 rows x 11 columns]

# %%
filtrado.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 714 entries, 0 to 890
# Data columns (total 11 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Survived    714 non-null    bool
#  1   Pclass      714 non-null    int64
#  2   Age         714 non-null    float64
#  3   SibSp       714 non-null    int64
#  4   Parch       714 non-null    int64
#  5   Fare        714 non-null    float64
#  6   Embarked_C  714 non-null    bool
#  7   Embarked_Q  714 non-null    bool
#  8   Embarked_S  714 non-null    bool
#  9   Sex_female  714 non-null    bool
#  10  Sex_male    714 non-null    bool
# dtypes: bool(6), float64(2), int64(3)
# memory usage: 37.7 KB

# %%
from pycaret.classification import *

# %%
exp = ClassificationExperiment()

exp.setup(data=filtrado, target = 'Survived', session_id=22, log_experiment="mlflow", experiment_name="titanic")

exp
# Out:
# <style type="text/css">
# #T_e42d6_row8_col1 {
#   background-color: lightgreen;
# }
# </style>
# <table id="T_e42d6">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_e42d6_level0_col0" class="col_heading level0 col0" >Description</th>
#       <th id="T_e42d6_level0_col1" class="col_heading level0 col1" >Value</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_e42d6_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_e42d6_row0_col0" class="data row0 col0" >Session id</td>
#       <td id="T_e42d6_row0_col1" class="data row0 col1" >22</td>
#     </tr>
#     <tr>
#       <th id="T_e42d6_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_e42d6_row1_col0" class="data row1 col0" >Target</td>
#       <td id="T_e42d6_row1_col1" class="data row1 col1" >Survived</td>
#     </tr>
#     <tr>
#       <th id="T_e42d6_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_e42d6_row2_col0" class="data row2 col0" >Target type</td>
#       <td id="T_e42d6_row2_col1" class="data row2 col1" >Binary</td>
#     </tr>
#     <tr>
#       <th id="T_e42d6_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_e42d6_row3_col0" class="data row3 col0" >Original data shape</td>
#       <td id="T_e42d6_row3_col1" class="data row3 col1" >(714, 11)</td>
#     </tr>
#     <tr>
#       <th id="T_e42d6_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_e42d6_row4_col0" class="data row4 col0" >Transformed data shape</td>
#       <td id="T_e42d6_row4_col1" class="data row4 col1" >(714, 11)</td>
#     </tr>
#     <tr>
#       <th id="T_e42d6_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_e42d6_row5_col0" class="data row5 col0" >Transformed train set shape</td>
#       <td id="T_e42d6_row5_col1" class="data row5 col1" >(499, 11)</td>
#     </tr>
#     <tr>
#       <th id="T_e42d6_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_e42d6_row6_col0" class="data row6 col0" >Transformed test set shape</td>
#       <td id="T_e42d6_row6_col1" class="data row6 col1" >(215, 11)</td>
#     </tr>
#     <tr>
#       <th id="T_e42d6_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_e42d6_row7_col0" class="data row7 col0" >Numeric features</td>
#       <td id="T_e42d6_row7_col1" class="data row7 col1" >5</td>
#     </tr>
#     <tr>
#       <th id="T_e42d6_level0_row8" class="row_heading level0 row8" >8</th>
#       <td id="T_e42d6_row8_col0" class="data row8 col0" >Preprocess</td>
#       <td id="T_e42d6_row8_col1" class="data row8 col1" >True</td>
#     </tr>
#     <tr>
#       <th id="T_e42d6_level0_row9" class="row_heading level0 row9" >9</th>
#       <td id="T_e42d6_row9_col0" class="data row9 col0" >Imputation type</td>
#       <td id="T_e42d6_row9_col1" class="data row9 col1" >simple</td>
#     </tr>
#     <tr>
#       <th id="T_e42d6_level0_row10" class="row_heading level0 row10" >10</th>
#       <td id="T_e42d6_row10_col0" class="data row10 col0" >Numeric imputation</td>
#       <td id="T_e42d6_row10_col1" class="data row10 col1" >mean</td>
#     </tr>
#     <tr>
#       <th id="T_e42d6_level0_row11" class="row_heading level0 row11" >11</th>
#       <td id="T_e42d6_row11_col0" class="data row11 col0" >Categorical imputation</td>
#       <td id="T_e42d6_row11_col1" class="data row11 col1" >mode</td>
#     </tr>
#     <tr>
#       <th id="T_e42d6_level0_row12" class="row_heading level0 row12" >12</th>
#       <td id="T_e42d6_row12_col0" class="data row12 col0" >Fold Generator</td>
#       <td id="T_e42d6_row12_col1" class="data row12 col1" >StratifiedKFold</td>
#     </tr>
#     <tr>
#       <th id="T_e42d6_level0_row13" class="row_heading level0 row13" >13</th>
#       <td id="T_e42d6_row13_col0" class="data row13 col0" >Fold Number</td>
#       <td id="T_e42d6_row13_col1" class="data row13 col1" >10</td>
#     </tr>
#     <tr>
#       <th id="T_e42d6_level0_row14" class="row_heading level0 row14" >14</th>
#       <td id="T_e42d6_row14_col0" class="data row14 col0" >CPU Jobs</td>
#       <td id="T_e42d6_row14_col1" class="data row14 col1" >-1</td>
#     </tr>
#     <tr>
#       <th id="T_e42d6_level0_row15" class="row_heading level0 row15" >15</th>
#       <td id="T_e42d6_row15_col0" class="data row15 col0" >Use GPU</td>
#       <td id="T_e42d6_row15_col1" class="data row15 col1" >False</td>
#     </tr>
#     <tr>
#       <th id="T_e42d6_level0_row16" class="row_heading level0 row16" >16</th>
#       <td id="T_e42d6_row16_col0" class="data row16 col0" >Log Experiment</td>
#       <td id="T_e42d6_row16_col1" class="data row16 col1" >MlflowLogger</td>
#     </tr>
#     <tr>
#       <th id="T_e42d6_level0_row17" class="row_heading level0 row17" >17</th>
#       <td id="T_e42d6_row17_col0" class="data row17 col0" >Experiment Name</td>
#       <td id="T_e42d6_row17_col1" class="data row17 col1" >titanic</td>
#     </tr>
#     <tr>
#       <th id="T_e42d6_level0_row18" class="row_heading level0 row18" >18</th>
#       <td id="T_e42d6_row18_col0" class="data row18 col0" >USI</td>
#       <td id="T_e42d6_row18_col1" class="data row18 col1" >9f81</td>
#     </tr>
#   </tbody>
# </table>
# 2025/03/20 15:43:41 INFO mlflow.tracking.fluent: Experiment with name 'titanic' does not exist. Creating a new experiment.

# %%
best = exp.compare_models()
# Out:
#
#
# Initiated  . . . . . . . . . . . . . . . . . .              15:43:41
# Status     . . . . . . . . . . . . . . . . . .  Loading Dependencies
# Estimator  . . . . . . . . . . . . . . . . . .     Compiling Library
# <style type="text/css">
# #T_17b20 th {
#   text-align: left;
# }
# #T_17b20_row0_col0, #T_17b20_row0_col2, #T_17b20_row0_col3, #T_17b20_row0_col4, #T_17b20_row1_col0, #T_17b20_row1_col1, #T_17b20_row1_col2, #T_17b20_row1_col3, #T_17b20_row1_col4, #T_17b20_row1_col5, #T_17b20_row1_col6, #T_17b20_row1_col7, #T_17b20_row2_col0, #T_17b20_row2_col1, #T_17b20_row2_col3, #T_17b20_row2_col4, #T_17b20_row2_col5, #T_17b20_row2_col6, #T_17b20_row2_col7, #T_17b20_row3_col0, #T_17b20_row3_col1, #T_17b20_row3_col2, #T_17b20_row3_col3, #T_17b20_row3_col5, #T_17b20_row3_col6, #T_17b20_row3_col7, #T_17b20_row4_col0, #T_17b20_row4_col1, #T_17b20_row4_col2, #T_17b20_row4_col3, #T_17b20_row4_col5, #T_17b20_row4_col6, #T_17b20_row4_col7, #T_17b20_row5_col0, #T_17b20_row5_col1, #T_17b20_row5_col2, #T_17b20_row5_col3, #T_17b20_row5_col4, #T_17b20_row5_col5, #T_17b20_row5_col6, #T_17b20_row5_col7, #T_17b20_row6_col0, #T_17b20_row6_col1, #T_17b20_row6_col2, #T_17b20_row6_col3, #T_17b20_row6_col4, #T_17b20_row6_col5, #T_17b20_row6_col6, #T_17b20_row6_col7, #T_17b20_row7_col0, #T_17b20_row7_col1, #T_17b20_row7_col2, #T_17b20_row7_col3, #T_17b20_row7_col4, #T_17b20_row7_col5, #T_17b20_row7_col6, #T_17b20_row7_col7, #T_17b20_row8_col0, #T_17b20_row8_col1, #T_17b20_row8_col2, #T_17b20_row8_col3, #T_17b20_row8_col4, #T_17b20_row8_col5, #T_17b20_row8_col6, #T_17b20_row8_col7, #T_17b20_row9_col0, #T_17b20_row9_col1, #T_17b20_row9_col2, #T_17b20_row9_col3, #T_17b20_row9_col4, #T_17b20_row9_col5, #T_17b20_row9_col6, #T_17b20_row9_col7, #T_17b20_row10_col0, #T_17b20_row10_col1, #T_17b20_row10_col2, #T_17b20_row10_col3, #T_17b20_row10_col4, #T_17b20_row10_col5, #T_17b20_row10_col6, #T_17b20_row10_col7, #T_17b20_row11_col0, #T_17b20_row11_col1, #T_17b20_row11_col2, #T_17b20_row11_col3, #T_17b20_row11_col4, #T_17b20_row11_col5, #T_17b20_row11_col6, #T_17b20_row11_col7, #T_17b20_row12_col0, #T_17b20_row12_col1, #T_17b20_row12_col2, #T_17b20_row12_col3, #T_17b20_row12_col4, #T_17b20_row12_col5, #T_17b20_row12_col6, #T_17b20_row12_col7, #T_17b20_row13_col0, #T_17b20_row13_col1, #T_17b20_row13_col2, #T_17b20_row13_col3, #T_17b20_row13_col4, #T_17b20_row13_col5, #T_17b20_row13_col6, #T_17b20_row13_col7, #T_17b20_row14_col0, #T_17b20_row14_col1, #T_17b20_row14_col2, #T_17b20_row14_col4, #T_17b20_row14_col5, #T_17b20_row14_col6, #T_17b20_row14_col7 {
#   text-align: left;
# }
# #T_17b20_row0_col1, #T_17b20_row0_col5, #T_17b20_row0_col6, #T_17b20_row0_col7, #T_17b20_row2_col2, #T_17b20_row3_col4, #T_17b20_row4_col4, #T_17b20_row14_col3 {
#   text-align: left;
#   background-color: yellow;
# }
# #T_17b20_row0_col8, #T_17b20_row1_col8, #T_17b20_row2_col8, #T_17b20_row4_col8, #T_17b20_row5_col8, #T_17b20_row6_col8, #T_17b20_row7_col8, #T_17b20_row8_col8, #T_17b20_row9_col8, #T_17b20_row10_col8, #T_17b20_row11_col8, #T_17b20_row12_col8, #T_17b20_row14_col8 {
#   text-align: left;
#   background-color: lightgrey;
# }
# #T_17b20_row3_col8, #T_17b20_row13_col8 {
#   text-align: left;
#   background-color: yellow;
#   background-color: lightgrey;
# }
# </style>
# <table id="T_17b20">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_17b20_level0_col0" class="col_heading level0 col0" >Model</th>
#       <th id="T_17b20_level0_col1" class="col_heading level0 col1" >Accuracy</th>
#       <th id="T_17b20_level0_col2" class="col_heading level0 col2" >AUC</th>
#       <th id="T_17b20_level0_col3" class="col_heading level0 col3" >Recall</th>
#       <th id="T_17b20_level0_col4" class="col_heading level0 col4" >Prec.</th>
#       <th id="T_17b20_level0_col5" class="col_heading level0 col5" >F1</th>
#       <th id="T_17b20_level0_col6" class="col_heading level0 col6" >Kappa</th>
#       <th id="T_17b20_level0_col7" class="col_heading level0 col7" >MCC</th>
#       <th id="T_17b20_level0_col8" class="col_heading level0 col8" >TT (Sec)</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_17b20_level0_row0" class="row_heading level0 row0" >gbc</th>
#       <td id="T_17b20_row0_col0" class="data row0 col0" >Gradient Boosting Classifier</td>
#       <td id="T_17b20_row0_col1" class="data row0 col1" >0.8076</td>
#       <td id="T_17b20_row0_col2" class="data row0 col2" >0.8584</td>
#       <td id="T_17b20_row0_col3" class="data row0 col3" >0.7190</td>
#       <td id="T_17b20_row0_col4" class="data row0 col4" >0.7949</td>
#       <td id="T_17b20_row0_col5" class="data row0 col5" >0.7501</td>
#       <td id="T_17b20_row0_col6" class="data row0 col6" >0.5950</td>
#       <td id="T_17b20_row0_col7" class="data row0 col7" >0.6016</td>
#       <td id="T_17b20_row0_col8" class="data row0 col8" >0.0440</td>
#     </tr>
#     <tr>
#       <th id="T_17b20_level0_row1" class="row_heading level0 row1" >lr</th>
#       <td id="T_17b20_row1_col0" class="data row1 col0" >Logistic Regression</td>
#       <td id="T_17b20_row1_col1" class="data row1 col1" >0.7977</td>
#       <td id="T_17b20_row1_col2" class="data row1 col2" >0.8554</td>
#       <td id="T_17b20_row1_col3" class="data row1 col3" >0.6995</td>
#       <td id="T_17b20_row1_col4" class="data row1 col4" >0.7923</td>
#       <td id="T_17b20_row1_col5" class="data row1 col5" >0.7355</td>
#       <td id="T_17b20_row1_col6" class="data row1 col6" >0.5735</td>
#       <td id="T_17b20_row1_col7" class="data row1 col7" >0.5831</td>
#       <td id="T_17b20_row1_col8" class="data row1 col8" >0.6590</td>
#     </tr>
#     <tr>
#       <th id="T_17b20_level0_row2" class="row_heading level0 row2" >catboost</th>
#       <td id="T_17b20_row2_col0" class="data row2 col0" >CatBoost Classifier</td>
#       <td id="T_17b20_row2_col1" class="data row2 col1" >0.7976</td>
#       <td id="T_17b20_row2_col2" class="data row2 col2" >0.8609</td>
#       <td id="T_17b20_row2_col3" class="data row2 col3" >0.7086</td>
#       <td id="T_17b20_row2_col4" class="data row2 col4" >0.7755</td>
#       <td id="T_17b20_row2_col5" class="data row2 col5" >0.7377</td>
#       <td id="T_17b20_row2_col6" class="data row2 col6" >0.5738</td>
#       <td id="T_17b20_row2_col7" class="data row2 col7" >0.5780</td>
#       <td id="T_17b20_row2_col8" class="data row2 col8" >0.7000</td>
#     </tr>
#     <tr>
#       <th id="T_17b20_level0_row3" class="row_heading level0 row3" >ridge</th>
#       <td id="T_17b20_row3_col0" class="data row3 col0" >Ridge Classifier</td>
#       <td id="T_17b20_row3_col1" class="data row3 col1" >0.7957</td>
#       <td id="T_17b20_row3_col2" class="data row3 col2" >0.8544</td>
#       <td id="T_17b20_row3_col3" class="data row3 col3" >0.6850</td>
#       <td id="T_17b20_row3_col4" class="data row3 col4" >0.8019</td>
#       <td id="T_17b20_row3_col5" class="data row3 col5" >0.7288</td>
#       <td id="T_17b20_row3_col6" class="data row3 col6" >0.5677</td>
#       <td id="T_17b20_row3_col7" class="data row3 col7" >0.5813</td>
#       <td id="T_17b20_row3_col8" class="data row3 col8" >0.0070</td>
#     </tr>
#     <tr>
#       <th id="T_17b20_level0_row4" class="row_heading level0 row4" >lda</th>
#       <td id="T_17b20_row4_col0" class="data row4 col0" >Linear Discriminant Analysis</td>
#       <td id="T_17b20_row4_col1" class="data row4 col1" >0.7957</td>
#       <td id="T_17b20_row4_col2" class="data row4 col2" >0.8541</td>
#       <td id="T_17b20_row4_col3" class="data row4 col3" >0.6850</td>
#       <td id="T_17b20_row4_col4" class="data row4 col4" >0.8019</td>
#       <td id="T_17b20_row4_col5" class="data row4 col5" >0.7288</td>
#       <td id="T_17b20_row4_col6" class="data row4 col6" >0.5677</td>
#       <td id="T_17b20_row4_col7" class="data row4 col7" >0.5813</td>
#       <td id="T_17b20_row4_col8" class="data row4 col8" >0.0110</td>
#     </tr>
#     <tr>
#       <th id="T_17b20_level0_row5" class="row_heading level0 row5" >ada</th>
#       <td id="T_17b20_row5_col0" class="data row5 col0" >Ada Boost Classifier</td>
#       <td id="T_17b20_row5_col1" class="data row5 col1" >0.7897</td>
#       <td id="T_17b20_row5_col2" class="data row5 col2" >0.8329</td>
#       <td id="T_17b20_row5_col3" class="data row5 col3" >0.7348</td>
#       <td id="T_17b20_row5_col4" class="data row5 col4" >0.7499</td>
#       <td id="T_17b20_row5_col5" c
# 2025/03/20 15:44:04 WARNING mlflow.models.model: Input example should be provided to infer model signature if the model signature is not provided when logging the model.
# 2025/03/20 15:44:04 WARNING mlflow.models.model: Input example should be provided to infer model signature if the model signature is not provided when logging the model.
# 2025/03/20 15:44:04 WARNING mlflow.models.model: Input example should be provided to infer model signature if the model signature is not provided when logging the model.
# 2025/03/20 15:44:05 WARNING mlflow.models.model: Input example should be provided to infer model signature if the model signature is not provided when logging the model.
# 2025/03/20 15:44:05 WARNING mlflow.models.model: Input example should be provided to infer model signature if the model signature is not provided when logging the model.
# 2025/03/20 15:44:05 WARNING mlflow.models.model: Input example should be provided to infer model signature if the model signature is not provided when logging the model.
# 2025/03/20 15:44:05 WARNING mlflow.models.model: Input example should be provided to infer model signature if the model signature is not provided when logging the model.
# 2025/03/20 15:44:06 WARNING mlflow.models.model: Input example should be provided to infer model signature if the model signature is not provided when logging the model.
# 2025/03/20 15:44:06 WARNING mlflow.models.model: Input example should be provided to infer model signature if the model signature is not provided when logging the model.
# 2025/03/20 15:44:06 WARNING mlflow.models.model: Input example should be provided to infer model signature if the model signature is not provided when logging the model.
# 2025/03/20 15:44:06 WARNING mlflow.models.model: Input example should be provided to infer model signature if the model signature is not provided when logging the model.
# 2025/03/20 15:44:07 WARNING mlflow.models.model: Input example should be provided to infer model signature if the model signature is not provided when logging the model.
# 2025/03/20 15:44:07 WARNING mlflow.models.model: Input example should be provided to infer model signature if the model signature is not provided when logging the model.
# 2025/03/20 15:44:07 WARNING mlflow.models.model: Input example should be provided to infer model signature if the model signature is not provided when logging the model.
# 2025/03/20 15:44:07 WARNING mlflow.models.model: Input example should be provided to infer model signature if the model signature is not provided when logging the model.

# %%
exp.evaluate_model(best)
# Out:
# interactive(children=(ToggleButtons(description='Plot Type:', icons=('',), options=(('Pipeline Plot', 'pipelin…

# %%
#run in line command : mlflow server to see results in mlflow
