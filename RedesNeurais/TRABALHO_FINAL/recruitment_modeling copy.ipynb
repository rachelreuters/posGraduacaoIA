# %%
import numpy
import pandas as pd
from sklearn.preprocessing import StandardScaler, MinMaxScaler
from sklearn.model_selection import StratifiedKFold
import seaborn
import tensorflow as tf
from sklearn.preprocessing import OneHotEncoder
from scikeras.wrappers import KerasClassifier
from sklearn.model_selection import GridSearchCV


print("Num GPUs Available: ", len(tf.config.list_physical_devices('GPU')))


recrutamento = pd.read_csv('recruitment_data.csv', sep=',', decimal='.')

# Instanciando o objeto One-Hot encoder, pois vai ser utilizada na coluna recrutamento Strategy
ohe = OneHotEncoder(handle_unknown='ignore')
# Fazendo a transformação
ohe_df = pd.DataFrame(ohe.fit_transform(recrutamento[['RecruitmentStrategy']]).toarray(), columns=['RecruitmentStrategy_1','RecruitmentStrategy_2','RecruitmentStrategy_3'])

# Agrupando a nova coluna com o df original
df = recrutamento.join(ohe_df)

recrutamento = df.drop(['RecruitmentStrategy'], axis=1)


corrPearson = recrutamento.corr('pearson')

seaborn.heatmap(corrPearson, annot=False, cmap='coolwarm', center=0)

features = list(recrutamento.columns.values)

classificacao = 'HiringDecision'

corrKendall = recrutamento.corr('kendall')

corrPearson = recrutamento.corr('pearson')

corrSpearman = recrutamento.corr('spearman')

tabela_correlacoes = pd.DataFrame()

tabela_correlacoes['kendal']= corrKendall['HiringDecision'].sort_values(ascending=False)
tabela_correlacoes['pearson']= corrPearson['HiringDecision'].sort_values(ascending=False)
tabela_correlacoes['spearman']= corrSpearman['HiringDecision'].sort_values(ascending=False)

tabela_correlacoes.drop(tabela_correlacoes[tabela_correlacoes['kendal']==1].index, inplace=True)

tabela_correlacoes

#Verifica-se que a estrategia de recrutamento  =1 que eh a agressiva, vai impactar muito na decisao final de contratacao

#removendo as features que tiveram indice de correlacao menor que 0.1
#tabela_correlacoes[tabela_correlacoes['kendal']<0.1].index

features.remove('PreviousCompanies')
features.remove('Age')
features.remove('Gender')
features.remove('DistanceFromCompany')

#Remove o output
features.remove(classificacao)

X = recrutamento[features].to_numpy() 
Y = recrutamento[classificacao].to_numpy()
# Out:
# Num GPUs Available:  1

# %%
#Verificando que os dados estao desbalanceados
seaborn.countplot(x=classificacao,data=recrutamento)
# Out:
# <AxesSubplot:xlabel='HiringDecision', ylabel='count'>

# %%
#Eh interessante aplicar  o SMOTE para reduzir o vies em direcao a classe de " Nao contratados "
#A tecnica de SMOTE gera dados pra classe menos favorecida utilizando tecnica de KNN e ao mesmo tempo interpolacao
from imblearn.over_sampling import SMOTE
oversample = SMOTE()
X, Y = oversample.fit_resample(X, Y)

# %%
#Agora os dados estao balanceados
seaborn.countplot(x=Y)
# Out:
# <AxesSubplot:ylabel='count'>

# %%
import matplotlib.pyplot as plt
STANDARD_SCALER = StandardScaler()
X_normalizado_standard = STANDARD_SCALER.fit_transform(X)


MIN_MAX_SCALER = MinMaxScaler(feature_range=(0, 1))
X_normalizado_min_max = MIN_MAX_SCALER.fit_transform(X)




from sklearn.preprocessing import PowerTransformer, QuantileTransformer

qt = QuantileTransformer(output_distribution='normal')


pt = PowerTransformer(method='yeo-johnson')

teste_yeo_johnson = pt.fit_transform(X)
teste_yeo_johnson = STANDARD_SCALER.fit_transform(teste_yeo_johnson)

teste_quantile = qt.fit_transform(X)
teste_quantile = STANDARD_SCALER.fit_transform(teste_quantile)


f, axs = plt.subplots(1, 5, figsize=(8, 4))
seaborn.kdeplot(X, ax=axs[0], legend=False,)
axs[0].set_title('Original', size=10)

seaborn.kdeplot(X_normalizado_standard, ax=axs[1], legend=False,)
axs[1].set_title('StandardScaler', size=10)

seaborn.kdeplot(X_normalizado_min_max, ax=axs[2], legend=False,)
axs[2].set_title('MinMAX', size=10)


seaborn.kdeplot(teste_yeo_johnson, ax=axs[3], legend=False)
axs[3].set_title('Yeo Johnson', size=10)

seaborn.kdeplot(teste_quantile, ax=axs[4], legend=False)
axs[4].set_title('Quantile', size=10)

f.tight_layout()

X_transformado = teste_quantile

# %%
# PARAMETROS DA REDE 
from enum import Enum

class LossFunction(Enum):
    MSE = "mse"
    BINARY_CROSS = "binary_crossentropy"
    CATEGORICAL_CROSS="categorical_crossentropy"


class Optimizer(Enum):
    ADAM = "adam"
    RMSPROP="rmsprop"

class Activation(Enum):
    SIGMOID = "sigmoid"
    TANH="tanh"
    RELU="relu"
    

class Metrics(Enum):
    ACCURACY = "accuracy"
    PRECISION="precision"
    RECALL="recall"


class KernelInit(Enum):
    UNIFORM= "uniform"
    NORMAL= "normal"
    HENORMAL="he_normal"
    GLOROTNORMAL ="glorot_normal"

# %%
from keras.callbacks import ReduceLROnPlateau

funcoes_ativacao = [Activation.TANH.value ]#, Activation.RELU.value] 
metrica = Metrics.ACCURACY.value
# SEED que controla a aleatoriedade 
random_seed = 22
tf.random.set_seed(random_seed)
# define the grid search parameters
neurons = [ X_transformado.shape[1]*4] #, X_transformado.shape[1]*3,X_transformado.shape[1]*4]
hidden_layers =[1] 
loss_function=[LossFunction.MSE.value]
optimezer_to_test= [Optimizer.ADAM.value]
batch_size= 32
lr = 0.00005
reduce_lr = ReduceLROnPlateau(monitor='val_loss', factor=0.1, patience=5, min_lr=lr)

def create_model(neurons, activation, hidden_layers, loss_function, optimizer):

    optimizer_instance = None
    if(optimizer == Optimizer.ADAM.value):
        optimizer_instance = tf.keras.optimizers.Adam(learning_rate=lr)
    elif(optimizer == Optimizer.RMSPROP.value):
        optimizer_instance = tf.keras.optimizers.RMSprop(learning_rate=lr)


    model = tf.keras.models.Sequential()
    for layer in range(hidden_layers): 
        model.add(tf.keras.layers.Dense(neurons, input_shape=(X_transformado.shape[1],),  activation=activation,
                                        kernel_initializer=KernelInit.NORMAL.value))
        #model.add(tf.keras.layers.Dropout(0.3))
    
    model.add(tf.keras.layers.Dense(1, activation=Activation.SIGMOID.value))

    model.compile(loss=loss_function, optimizer=optimizer_instance, metrics=[Metrics.ACCURACY.value])
    return model


# create model
model = KerasClassifier(model=create_model,batch_size=batch_size, verbose=1)

param_grid = dict(epochs=[1500], model__neurons=neurons, model__activation=funcoes_ativacao,
                  model__hidden_layers= hidden_layers, model__loss_function= loss_function,
                  model__optimizer = optimezer_to_test  )
grid = GridSearchCV(estimator=model, param_grid=param_grid, cv=5)
grid_result = grid.fit(X_transformado, Y) #, callbacks=[reduce_lr])
# summarize results
print("Best: %f using %s" % (grid_result.best_score_, grid_result.best_params_))
means = grid_result.cv_results_['mean_test_score']
stds = grid_result.cv_results_['std_test_score']
params = grid_result.cv_results_['params']
for mean, stdev, param in zip(means, stds, params):
    print("%f (%f) with: %r" % (mean, stdev, param))
# Out:
# Epoch 1/1500
# 52/52 [==============================] - 1s 4ms/step - loss: 0.2551 - accuracy: 0.4698
# Epoch 2/1500
# 52/52 [==============================] - 0s 4ms/step - loss: 0.2481 - accuracy: 0.5465
# Epoch 3/1500
# 52/52 [==============================] - 0s 3ms/step - loss: 0.2414 - accuracy: 0.6196
# Epoch 4/1500
# 52/52 [==============================] - 0s 3ms/step - loss: 0.2350 - accuracy: 0.6709
# Epoch 5/1500
# 52/52 [==============================] - 0s 3ms/step - loss: 0.2288 - accuracy: 0.7174
# Epoch 6/1500
# 52/52 [==============================] - 0s 3ms/step - loss: 0.2230 - accuracy: 0.7415
# Epoch 7/1500
# 52/52 [==============================] - 0s 3ms/step - loss: 0.2174 - accuracy: 0.7597
# Epoch 8/1500
# 52/52 [==============================] - 0s 3ms/step - loss: 0.2121 - accuracy: 0.7736
# Epoch 9/1500
# 52/52 [==============================] - 0s 4ms/step - loss: 0.2070 - accuracy: 0.7862
# Epoch 10/1500
# 52/52 [==============================] - 0s 3ms/step - loss: 0.2022 - accuracy: 0.7977
# Epoch 11/1500
# 52/52 [==============================] - 0s 3ms/step - loss: 0.1976 - accuracy: 0.8013
# Epoch 12/1500
# 52/52 [==============================] - 0s 3ms/step - loss: 0.1932 - accuracy: 0.8043
# Epoch 13/1500
# 52/52 [==============================] - 0s 3ms/step - loss: 0.1890 - accuracy: 0.8110
# Epoch 14/1500
# 52/52 [==============================] - 0s 3ms/step - loss: 0.1851 - accuracy: 0.8122
# Epoch 15/1500
# 52/52 [==============================] - 0s 4ms/step - loss: 0.1814 - accuracy: 0.8182
# Epoch 16/1500
# 52/52 [==============================] - 0s 4ms/step - loss: 0.1778 - accuracy: 0.8243
# Epoch 17/1500
# 52/52 [==============================] - 0s 5ms/step - loss: 0.1745 - accuracy: 0.8279
# Epoch 18/1500
# 52/52 [==============================] - 0s 5ms/step - loss: 0.1713 - accuracy: 0.8291
# Epoch 19/1500
# 52/52 [==============================] - 0s 4ms/step - loss: 0.1684 - accuracy: 0.8285
# Epoch 20/1500
# 52/52 [==============================] - 0s 4ms/step - loss: 0.1656 - accuracy: 0.8273
# Epoch 21/1500
# 52/52 [==============================] - 0s 4ms/step - loss: 0.1630 - accuracy: 0.8291
# Epoch 22/1500
# 52/52 [==============================] - 0s 4ms/step - loss: 0.1606 - accuracy: 0.8285
# Epoch 23/1500
# 52/52 [==============================] - 0s 4ms/step - loss: 0.1583 - accuracy: 0.8291
# Epoch 24/1500
# 52/52 [==============================] - 0s 5ms/step - loss: 0.1562 - accuracy: 0.8297
# Epoch 25/1500
# 52/52 [==============================] - 0s 4ms/step - loss: 0.1541 - accuracy: 0.8297
# Epoch 26/1500
# 52/52 [==============================] - 0s 4ms/step - loss: 0.1523 - accuracy: 0.8297
# Epoch 27/1500
# 52/52 [==============================] - 0s 4ms/step - loss: 0.1505 - accuracy: 0.8297
# Epoch 28/1500
# 52/52 [==============================] - 0s 4ms/step - loss: 0.1489 - accuracy: 0.8303
# Epoch 29/1500
# 52/52 [==============================] - 0s 4ms/step - loss: 0.1474 - accuracy: 0.8315
# Epoch 30/1500
# 52/52 [==============================] - 0s 4ms/step - loss: 0.1459 - accuracy: 0.8309
# Epoch 31/1500
# 52/52 [==============================] - 0s 3ms/step - loss: 0.1446 - accuracy: 0.8315
# Epoch 32/1500
# 52/52 [==============================] - 0s 4ms/step - loss: 0.1434 - accuracy: 0.8321
# Epoch 33/1500
# 52/52 [==============================] - 0s 3ms/step - loss: 0.1422 - accuracy: 0.8315
# Epoch 34/1500
# 52/52 [==============================] - 0s 3ms/step - loss: 0.1411 - accuracy: 0.8315
# Epoch 35/1500
# 52/52 [==============================] - 0s 3ms/step - loss: 0.1401 - accuracy: 0.8315
# Epoch 36/1500
# 52/52 [==============================] - 0s 3ms/step - loss: 0.1392 - accuracy: 0.8315
# Epoch 37/1500
# 52/52 [==============================] - 0s 3ms/step - loss: 0.1383 - accuracy: 0.8315
# Epoch 38/1500
# 52/52 [==============================] - 0s 3ms/step - loss: 0.1374 - accuracy: 0.8315
# Epoch 39/1500
# 52/52 [==============================] - 0s 3ms/step - loss: 0.1367 - accuracy: 0.8315
# Epoch 40/1500
# 52/52 [==============================] - 0s 4ms/step - loss: 0.1359 - accuracy: 0.8315
# Epoch 41/1500
# 52/52 [==============================] - 0s 3ms/step - loss: 0.1353 - accuracy: 0.8345
# Epoch 42/1500
# 52/52 [==============================] - 0s 3ms/step - loss: 0.1346 - accuracy: 0.8333
# Epoch 43/1500
# 52/52 [==============================] - 0s 3ms/step - loss: 0.1340 - accuracy: 0.8333
# Epoch 44/1500
# 52/52 [==============================] - 0s 3ms/step - loss: 0.1335 - accuracy: 0.8339
# Epoch 45/1500
# 52/52 [==============================] - 0s 3ms/step - loss: 0.1329 - accuracy: 0.8333
# Epoch 46/1500
# 52/52 [==============================] - 0s 3ms/step - loss: 0.1325 - accuracy: 0.8345
# Epoch 47/1500
# 52/52 [==============================] - 0s 3ms/step - loss: 0.1320 - accuracy: 0.8351
# Epoch 48/1500
# 52/52 [==============================] - 0s 3ms/step - loss: 0.1315 - accuracy: 0.8351
# Epoch 49/1500
# 52/52 [==============================] - 0s 4ms/step - loss: 0.1311 - accuracy: 0.8351
# Epoch 50/1500
# 52/52 [==============================] - 0s 3ms/step - loss: 0.1308 - accuracy: 0.8357
# Epoch 51/1500
# 52/52 [==============================] - 0s 3ms/step - loss: 0.1304 - accuracy: 0.8351
# Epoch 52/1500
# 52/52 [==============================] - 0s 3ms/step - loss: 0.1301 - accuracy: 0.8351
# Epoch 53/1500
# 52/52 [==============================] - 0s 3ms/step - loss: 0.1297 - accuracy: 0.8351
# Epoch 54/1500
# 52/52 [==============================] - 0s 3ms/step - loss: 0.1294 - accuracy: 0.8357
# Epoch 55/1500
# 52/52 [==============================] - 0s 3ms/step - loss: 0.1292 - accuracy: 0.8357
# Epoch 56/1500
# 52/52 [==============================] - 0s 3ms/step - loss: 0.1289 - accuracy: 0.8364
# Epoch 57/1500
# 52/52 [==============================] - 0s 4ms/step - loss: 0.1286 - accuracy: 0.8357
# Epoch 58/1500
# 52/52 [==============================] - 0s 3ms/step - loss: 0.1284 - accuracy: 0.8351
# Epoch 59/1500
# 52/52 [==============================] - 0s 3ms/step - loss: 0.1282 - accuracy: 0.8345
# Epoch 60/1500
# 52/52 [==============================] - 0s 3ms/step - loss: 0.1279 - accuracy: 0.8339
# Epoch 61/1500
# 52/52 [==============================] - 0s 3ms/step - loss: 0.1277 - accuracy: 0.8339
# Epoch 62/1500
# 52/52 [==============================] - 0s 3ms/step - loss: 0.1276 - accuracy: 0.8351
# Epoch 63/1500
# 52/52 [==============================] - 0s 3ms/step - loss: 0.1274 - accuracy: 0.8345
# Epoch 64/1500
# 52/52 [==============================] - 0s 3ms/step - loss: 0.1272 - accuracy: 0.8345
# Epoch 65/1500
# 52/52 [==============================] - 0s 4ms/step - loss: 0.1271 - accuracy: 0.8351
# Epoch 66/1500
# 52/52 [==============================] - 0s 3ms/step - loss: 0.1269 - accuracy: 0.8345
# Epoch 67/1500
# 52/52 [==============================] - 0s 3ms/step - loss: 0.1268 - accuracy: 0.8345
# Epoch 68/1500
# 52/52 [==============================] - 0s 3ms/step - loss: 0.1266 - accuracy: 0.8351
# Epoch 69/1500
# 52/52 [==============================] - 0s 3ms/step - loss: 0.1265 - accuracy: 0.8351
# Epoch 70/1500
# 52/52 [==============================] - 0s 3ms/step - loss: 0.1263 - accuracy: 0.8357
# Epoch 71/1500
# 52/52 [==============================] - 0s 3ms/step - loss: 0.1262 - accuracy: 0.8357
# Epoch 72/1500
# 52/52 [==============================] - 0s 3ms/step - loss: 0.1261 - accuracy: 0.8351
# Epoch 73/1500
# 52/52 [==============================] - 0s 4ms/step - loss: 0.1260 - accuracy: 0.8351
# Epoch 74/1500
# 52/52 [==============================] - 0s 3ms/step - loss: 0.1259 - accuracy: 0.8351
# Epoch 75/1500
# 52/52 [==============================] - 0s 3ms/step - loss: 0.1258 - accuracy: 0.8345
# Epoch 76/1500
# 52/52 [==============================] - 0s 3ms/step - loss: 0.1257 - accuracy: 0.8351
# Epoch 77/1500
# 52/52 [==============================] - 0s 3ms/step - loss: 0.1256 - accuracy: 0.8351
# Epoch 78/1500
# 52/52 [==============================] - 0s 3ms/step - loss: 0.1255 - accuracy: 0.8364
# Epoch 79/1500
# 52/52 [==============================] - 0s 3ms/step - loss: 0.1255 - accuracy: 0.8357
# Epoch 80/1500
# 52/52 [==============================] - 0s 3ms/step - loss: 0.1254 - accuracy: 0.8339
# Epoch 81/1500
# 52/52 [==============================] - 0s 4ms/step - loss: 0.1253 - accuracy: 0.8351
# Epoch 82/1500
# 52/52 [==============================] - 0s 3ms/step - loss: 0.1253 - accuracy: 0.8351
# Epoch 83/1500
# 52/52 [==============================] - 0s 3ms/step - loss: 0.1252 - accuracy: 0.8345
# Epoch 84/1500
# 52/52 [==============================] - 0s 3ms/step - loss: 0.1251 - accuracy: 0.8345
# Epoch 85/1500
# 52/52 [==============================] - 0s 3ms/step - loss: 0.1251 - accuracy: 0.8351
# Epoch 86/1500
# 52/52 [==============================] - 0s 3ms/step - loss: 0.1250 - accuracy: 0.8345
# Epoch 87/1500
# 52/52 [==============================] - 0s 3ms/step - loss: 0.1249 - accuracy: 0.8345
# Epoch 88/1500
# 52/52 [==============================] - 0s 3ms/step - loss: 0.1249 - accuracy: 0.8351
# Epoch 89/1500
# 52/52 [==============================] - 0s 4ms/step - loss: 0.1248 - accuracy: 0.8345
# Epoch 90/1500
# 52/52 [==============================] - 0s 3ms/step - loss: 0.1248 - accuracy: 0.8357
# Epoch 91/1500
# 52/52 [==============================] - 0s 3ms/step - loss: 0.1247 - accuracy: 0.8357
# Epoch 92/1500
# 52/52 [==============================] - 0s 3ms/step - loss: 0.1247 - accuracy: 0.8357
# Epoch 93/1500
# 52/52 [==============================] - 0s 3ms/step - loss: 0.1247 - accuracy: 0.8351
# Epoch 94/1500
# 52/52 [==============================] - 0s 3ms/step - loss: 0.1246 - accuracy: 0.8357
# Epoch 95/1500
# 52/52 [==============================] - 0s 3ms/step - loss: 0.1246 - accuracy: 0.8357
# Epoch 96/1500
# 52/52 [==============================] - 0s 3ms/step - loss: 0.1245 - accuracy: 0.8357
# Epoch 97/1500
# 52/52 [==============================] - 0s 4ms/step - loss: 0.1245 - accuracy: 0.8357
# Epoch 98/1500
# 52/52 [==============================] - 0s 3ms/step - loss: 0.1245 - accuracy: 0.8357
# Epoch 99/1500
# 52/52 [==============================] - 0s 3ms/step - loss: 0.1244 - accuracy: 0.8364
# Epoch 100/1500
# 52/52 [==============================] - 0s 3ms/step - loss: 0.1244 - accuracy: 0.8364
# Epoch 101/1500
# 52/52 [==============================] - 0s 3ms/step - loss: 0.1244 - accuracy: 0.8364
# Epoch 102/1500
# 52/52 [==============================] - 0s 3ms/step - loss: 0.1243 - accuracy: 0.8364
# Epoch 103/1500
# 52/52 [==============================] - 0s 3ms/step - loss: 0.1243 - accuracy: 0.8357
# Epoch 104/1500
# 52/52 [==============================] - 0s 3ms/step - loss: 0.1243 - accuracy: 0.8357
# Epoch 105/1500
# 52/52 [==============================] - 0s 4ms/step - loss: 0.1242 - accuracy: 0.8351
# Epoch 106/1500
# 52/52 [==============================] - 0s 3ms/step - loss: 0.1242 - accuracy: 0.8351
# Epoch 107/1500
# 52/52 [==============================] - 0s 3ms/step - loss: 0.1242 - accuracy: 0.8351
# Epoch 108/1500
# 52/52 [==============================] - 0s 4ms/step - loss: 0.1242 - accuracy: 0.8351
# Epoch 109/1500
# 52/52 [==============================] - 0s 4ms/step - loss: 0.1241 - accuracy: 0.8351
# Epoch 110/1500
# 52/52 [==============================] - 0s 3ms/step - loss: 0.1241 - accuracy: 0.8351
# Epoch 111/1500
# 52/52 [==============================] - 0s 3ms/step - loss: 0.1241 - accuracy: 0.8357
# Epoch 112/1500
# 52/52 [==============================] - 0s 3ms/step - loss: 0.1241 - accuracy: 0.8351
# Epoch 113/1500
# 52/52 [==============================] - 0s 4ms/step - loss: 0.1240 - accuracy: 0.8357
# Epoch 114/1500
# 52/52 [==============================] - 0s 3ms/step - loss: 0.1240 - accuracy: 0.8351
# Epoch 115/1500
# 52/52 [==============================] - 0s 3ms/step - loss: 0.1240 - accuracy: 0.8351
# Epoch 116/1500
# 52/52 [==============================] - 0s 3ms/step - loss: 0.1240 - accuracy: 0.8357
# Epoch 117/1500
# 52/52 [==============================] - 0s 3ms/step - loss: 0.1240 - accuracy: 0.8351
# Epoch 118/1500
# 52/52 [==============================] - 0s 3ms/step - loss: 0.1240 - accuracy: 0.8351
# Epoch 119/1500
# 52/52 [==============================] - 0s 3ms/step - loss: 0.1240 - accuracy: 0.8357
# Epoch 120/1500
# 52/52 [==============================] - 0s 4ms/step - loss: 0.1239 - accuracy: 0.8357
# Epoch 121/1500
# 52/52 [==============================] - 0s 3ms/step - loss: 0.1239 - accuracy: 0.8370
# Epoch 122/1500
# 52/52 [==============================] - 0s 3ms/step - loss: 0.1239 - accuracy: 0.8357
# Epoch 123/1500
# 52/52 [==============================] - 0s 3ms/step - loss: 0.1239 - accuracy: 0.8357
# Epoch 124/1500
# 52/52 [==============================] - 0s 3ms/step - loss: 0.1239 - accuracy: 0.8357
# Epoch 125/1500
# 52/52 [==============================] - 0s 3ms/step - loss: 0.1238 - accuracy: 0.8370
# Epoch 126/1500
# 52/52 [==============================] - 0s 3ms/step - loss: 0.1238 - accuracy: 0.8370
# Epoch 127/1500
# 52/52 [==============================] - 0s 3ms/step - loss: 0.1238 - accuracy: 0.8370
# Epoch 128/1500
# 52/52 [==============================] - 0s 4ms/step - loss: 0.1238 - accuracy: 0.8357
# Epoch 129/1500
# 52/52 [==============================] - 0s 3ms/step - loss: 0.1238 - accuracy: 0.8357
# Epoch 130/1500
# 52/52 [==============================] - 0s 3ms/step - loss: 0.1238 - accuracy: 0.8364
# Epoch 131/1500
# 52/52 [==============================] - 0s 3ms/step - loss: 0.1238 - accuracy: 0.8382
# Epoch 132/1500
# 52/52 [==============================] - 0s 3ms/step - loss: 0.1238 - accuracy: 0.8382
# Epoch 133/1500
# 52/52 [==============================] - 0s 3ms/step - loss: 0.1237 - accuracy: 0.8376
# Epoch 134/1500
# 52/52 [==============================] - 0s 3ms/step - loss: 0.1237 - accuracy: 0.8382
# Epoch 135/1500
# 52/52 [==============================] - 0s 3ms/step - loss: 0.1237 - accuracy: 0.8382
# Epoch 136/1500
# 52/52 [==============================] - 0s 4ms/step - loss: 0.1237 - accuracy: 0.8376
# Epoch 137/1500
# 52/52 [==============================] - 0s 3ms/step - loss: 0.1237 - accuracy: 0.8376
# Epoch 138/1500
# 52/52 [==============================] - 0s 3ms/step - loss: 0.1237 - accuracy: 0.8382
# Epoch 139/1500
# 52/52 [==============================] - 0s 3ms/step - loss: 0.1237 - accuracy: 0.8382
# Epoch 140/1500
# 52/52 [==============================] - 0s 3ms/step - loss: 0.1237 - accuracy: 0.8382
# Epoch 141/1500
# 52/52 [==============================] - 0s 3ms/step - loss: 0.1237 - accuracy: 0.8382
# Epoch 142/1500
# 52/52 [==============================] - 0s 3ms/step - loss: 0.1236 - accuracy: 0.8382
# Epoch 143/1500
# 52/52 [==============================] - 0s 4ms/step - loss: 0.1236 - accuracy: 0.8382
# Epoch 144/1500
# 52/52 [==============================] - 0s 3ms/step - loss: 0.1236 - accuracy: 0.8382
# Epoch 145/1500
# 52/52 [==============================] - 0s 3ms/step - loss: 0.1236 - accuracy: 0.8382
# Epoch 146/1500
# 52/52 [==============================] - 0s 3ms/step - loss: 0.1236 - accuracy: 0.8382
# Epoch 147/1500
# 52/52 [==============================] - 0s 3ms/step - loss: 0.1236 - accuracy: 0.8382
# Epoch 148/1500
# 52/52 [==============================] - 0s 3ms/step - loss: 0.1236 - accuracy: 0.8388
# Epoch 149/1500
# 52/52 [==============================] - 0s 3ms/step - loss: 0.1236 - accuracy: 0.8382
# Epoch 150/1500
# 52/52 [==============================] - 0s 4ms/step - loss: 0.1236 - accuracy: 0.8388
# Epoch 151/1500
# 52/52 [==============================] - 0s 3ms/step - loss: 0.1236 - accuracy: 0.8388
# Epoch 152/1500
# 52/52 [==============================] - 0s 3ms/step - loss: 0.1236 - accuracy: 0.8388
# Epoch 153/1500
# 52/52 [==============================] - 0s 3ms/step - loss: 0.1235 - accuracy: 0.8388
# Epoch 154/1500
# 52/52 [==============================] - 0s 3ms/step - loss: 0.1235 - accuracy: 0.8388
# Epoch 155/1500
# 52/52 [==============================] - 0s 3ms/step - loss: 0.1235 - accuracy: 0.8388
# Epoch 156/1500
# 52/52 [==============================] - 0s 4ms/step - loss: 0.1235 - accuracy: 0.8388
# Epoch 157/1500
# 52/52 [==============================] - 0s 4ms/step - loss: 0.1235 - accuracy: 0.8388
# Epoch 158/1500
# 52/52 [==============================] - 0s 4ms/step - loss: 0.1235 - accuracy: 0.8388
# Epoch 159/1500
# 52/52 [==============================] - 0s 3ms/step - loss: 0.1235 - accuracy: 0.8382
# Epoch 160/1500
# 52/52 [==============================] - 0s 4ms/step - loss: 0.1235 - accuracy: 0.8382
# Epoch 161/1500
# 52/52 [==============================] - 0s 4ms/step - loss: 0.1235 - accuracy: 0.8388
# Epoch 162/1500
# 52/52 [==============================] - 0s 3ms/step - loss: 0.1235 - accuracy: 0.8388
# Epoch 163/1500
# 52/52 [==============================] - 0s 3ms/step - loss: 0.1235 - accuracy: 0.8382
# Epoch 164/1500
# 52/52 [==============================] - 0s 4ms/step - loss: 0.1235 - accuracy: 0.8382
# Epoch 165/1500
# 52/52 [==============================] - 0s 3ms/step - loss: 0.1234 - accuracy: 0.8376
# Epoch 166/1500
# 52/52 [==============================] - 0s 3ms/step - loss: 0.1234 - accuracy: 0.8382
# Epoch 167/1500
# 52/52 [==============================] - 0s 3ms/step - loss: 0.1234 - accuracy: 0.8382
# Epoch 168/1500
# 52/52 [==============================] - 0s 3ms/step - loss: 0.1234 - accuracy: 0.8382
# Epoch 169/1500
# 52/52 [==============================] - 0s 3ms/step - loss: 0.1234 - accuracy: 0.8376
# Epoch 170/1500
# 52/52 [==============================] - 0s 3ms/step - loss: 0.1234 - accuracy: 0.8388
# Epoch 171/1500
# 52/52 [==============================] - 0s 4ms/step - loss: 0.1234 - accuracy: 0.8376
# Epoch 172/1500
# 52/52 [==============================] - 0s 3ms/step - loss: 0.1234 - accuracy: 0.8382
# Epoch 173/1500
# 52/52 [==============================] - 0s 3ms/step - loss: 0.1234 - accuracy: 0.8382
# Epoch 174/1500
# 52/52 [==============================] - 0s 3ms/step - loss: 0.1234 - accuracy: 0.8388
# Epoch 175/1500
# 52/52 [==============================] - 0s 3ms/step - loss: 0.1234 - accuracy: 0.8394
# Epoch 176/1500
# 52/52 [==============================] - 0s 3ms/step - loss: 0.1234 - accuracy: 0.8388
# Epoch 177/1500
# 52/52 [==============================] - 0s 3ms/step - loss: 0.1234 - accuracy: 0.8382
# Epoch 178/1500
# 52/52 [==============================] - 0s 3ms/step - loss: 0.1234 - accuracy: 0.8394
# Epoch 179/1500
# 52/52 [==============================] - 0s 4ms/step - loss: 0.1233 - accuracy: 0.8394
# Epoch 180/1500
# 52/52 [==============================] - 0s 3ms/step - loss: 0.1233 - accuracy: 0.8394
# Epoch 181/1500
# 52/52 [==============================] - 0s 3ms/step - loss: 0.1233 - accuracy: 0.8388
# Epoch 182/1500
# 52/52 [==============================] - 0s 3ms/step - loss: 0.1233 - accuracy: 0.8394
# Epoch 183/1500
# 52/52 [==============================] - 0s 3ms/step - loss: 0.1233 - accuracy: 0.8394
# Epoch 184/1500
# 52/52 [==============================] - 0s 3ms/step - loss: 0.1233 - accuracy: 0.8394
# Epoch 185/1500
# 52/52 [==============================] - 0s 3ms/step - loss: 0.1233 - accuracy: 0.8394
# Epoch 186/1500
# 52/52 [==============================] - 0s 4ms/step - loss: 0.1233 - accuracy: 0.8394
# Epoch 187/1500
# 52/52 [==============================] - 0s 3ms/step - loss: 0.1233 - accuracy: 0.8388
# Epoch 188/1500
# 52/52 [==============================] - 0s 3ms/step - loss: 0.1233 - accuracy: 0.8382
# Epoch 189/1500
# 52/52 [==============================] - 0s 3ms/step - loss: 0.1233 - accuracy: 0.8394
# Epoch 190/1500
# 52/52 [==============================] - 0s 3ms/step - loss: 0.1233 - accuracy: 0.8394
# Epoch 191/1500
# 52/52 [==============================] - 0s 3ms/step - loss: 0.1233 - accuracy: 0.8394
# Epoch 192/1500
# 52/52 [==============================] - 0s 3ms/step - loss: 0.1233 - accuracy: 0.8394
# Epoch 193/1500
# 52/52 [==============================] - 0s 4ms/step - loss: 0.1233 - accuracy: 0.8394
# Epoch 194/1500
# 52/52 [==============================] - 0s 3ms/step - loss: 0.1233 - accuracy: 0.8400
# Epoch 195/1500
# 52/52 [==============================] - 0s 3ms/step - loss: 0.1233 - accuracy: 0.8388
# Epoch 196/1500
# 52/52 [==============================] - 0s 3ms/step - loss: 0.1232 - accuracy: 0.8394
# Epoch 197/1500
# 52/52 [==============================] - 0s 3ms/step - loss: 0.1232 - accuracy: 0.8394
# Epoch 198/1500
# 52/52 [==============================] - 0s 3ms/step - loss: 0.1232 - accuracy: 0.8400
# Epoch 199/1500
# 52/52 [==============================] - 0s 4ms/step - loss: 0.1232 - accuracy: 0.8400
# Epoch 200/1500
# 52/52 [==============================] - 0s 3ms/step - loss: 0.1232 - accuracy: 0.8388
# Epoch 201/1500
# 52/52 [==============================] - 0s 3ms/step - loss: 0.1232 - accuracy: 0.8394
# Epoch 202/1500
# 52/52 [==============================] - 0s 3ms/step - loss: 0.1232 - accuracy: 0.8400
# Epoch 203/1500
# 52/52 [==============================] - 0s 3ms/step - loss: 0.1232 - accuracy: 0.8400
# Epoch 204/1500
# 52/52 [==============================] - 0s 3ms/step - loss: 0.1232 - accuracy: 0.8388
# Epoch 205/1500
# 52/52 [==============================] - 0s 3ms/step - loss: 0.1232 - accuracy: 0.8388
# Epoch 206/1500
# 52/52 [==============================] - 0s 4ms/step - loss: 0.1232 - accuracy: 0.8388
# Epoch 207/1500
# 52/52 [==============================] - 0s 3ms/step - loss: 0.1232 - accuracy: 0.8394
# Epoch 208/1500
# 52/52 [==============================] - 0s 3ms/step - loss: 0.1232 - accuracy: 0.8394
# Epoch 209/1500
# 52/52 [==============================] - 0s 3ms/step - loss: 0.1231 - accuracy: 0.8394
# Epoch 210/1500
# 52/52 [==============================] - 0s 3ms/step - loss: 0.1232 - accuracy: 0.8388
# Epoch 211/1500
# 52/52 [==============================] - 0s 3ms/step - loss: 0.1232 - accuracy: 0.8388
# Epoch 212/1500
# 52/52 [==============================] - 0s 4ms/step - loss: 0.1231 - accuracy: 0.8382
# Epoch 213/1500
# 52/52 [==============================] - 0s 3ms/step - loss: 0.1231 - accuracy: 0.8382
# Epoch 214/1500
# 52/52 [==============================] - 0s 3ms/step - loss: 0.1231 - accuracy: 0.8388
# Epoch 215/1500
# 52/52 [==============================] - 0s 3ms/step - loss: 0.1231 - accuracy: 0.8388
# Epoch 216/1500
# 52/52 [==============================] - 0s 3ms/step - loss: 0.1231 - accuracy: 0.8388
# Epoch 217/1500
# 52/52 [==============================] - 0s 3ms/step - loss: 0.1231 - accuracy: 0.8394
# Epoch 218/1500
# 52/52 [==============================] - 0s 3ms/step - loss: 0.1231 - accuracy: 0.8394
# Epoch 219/1500
# 52/52 [==============================] - 0s 4ms/step - loss: 0.1231 - accuracy: 0.8388
# Epoch 220/1500
# 52/52 [==============================] - 0s 3ms/step - loss: 0.1231 - accuracy: 0.8388
# Epoch 221/1500
# 52/52 [==============================] - 0s 3ms/step - loss: 0.1231 - accuracy: 0.8394
# Epoch 222/1500
# 52/52 [==============================] - 0s 3ms/step - loss: 0.1231 - accuracy: 0.8382
# Epoch 223/1500
# 52/52 [==============================] - 0s 3ms/step - loss: 0.1231 - accuracy: 0.8394
# Epoch 224/1500
# 52/52 [==============================] - 0s 3ms/step - loss: 0.1231 - accuracy: 0.8388
# Epoch 225/1500
# 52/52 [==============================] - 0s 4ms/step - loss: 0.1231 - accuracy: 0.8388
# Epoch 226/1500
# 52/52 [==============================] - 0s 3ms/step - loss: 0.1231 - accuracy: 0.8400
# Epoch 227/1500
# 52/52 [==============================] - 0s 3ms/step - loss: 0.1231 - accuracy: 0.8394
# Epoch 228/1500
# 52/52 [==============================] - 0s 3ms/step - loss: 0.1231 - accuracy: 0.8388
# Epoch 229/1500
# 52/52 [==============================] - 0s 3ms/step - loss: 0.1230 - accuracy: 0.8388
# Epoch 230/1500
# 52/52 [==============================] - 0s 3ms/step - loss: 0.1230 - accuracy: 0.8382
# Epoch 231/1500
# 52/52 [==============================] - 0s 4ms/step - loss: 0.1230 - accuracy: 0.8388
# Epoch 232/1500
# 52/52 [==============================] - 0s 3ms/step - loss: 0.1230 - accuracy: 0.8394
# Epoch 233/1500
# 52/52 [==============================] - 0s 3ms/step - loss: 0.1230 - accuracy: 0.8394
# Epoch 234/1500
# 52/52 [==============================] - 0s 3ms/step - loss: 0.1230 - accuracy: 0.8382
# Epoch 235/1500
# 52/52 [==============================] - 0s 3ms/step - loss: 0.1230 - accuracy: 0.8388
# Epoch 236/1500
# 52/52 [==============================] - 0s 3ms/step - loss: 0.1230 - accuracy: 0.8394
# Epoch 237/1500
# 52/52 [==============================] - 0s 4ms/step - loss: 0.1230 - accuracy: 0.8394
# Epoch 238/1500
# 52/52 [==============================] - 0s 3ms/step - loss: 0.1230 - accuracy: 0.8394
# Epoch 239/1500
# 52/52 [==============================] - 0s 3ms/step - loss: 0.1230 - accuracy: 0.8394
# Epoch 240/1500
# 52/52 [==============================] - 0s 3ms/step - loss: 0.1230 - accuracy: 0.8400
# Epoch 241/1500
# 52/52 [==============================] - 0s 3ms/step - loss: 0.1230 - accuracy: 0.8400
# Epoch 242/1500
# 52/52 [==============================] - 0s 3ms/step - loss: 0.1230 - accuracy: 0.8400
# Epoch 243/1500
# 52/52 [==============================] - 0s 3ms/step - loss: 0.1230 - accuracy: 0.8400
# Epoch 244/1500
# 52/52 [==============================] - 0s 4ms/step - loss: 0.1230 - accuracy: 0.8388
# Epoch 245/1500
# 52/52 [==============================] - 0s 4ms/step - loss: 0.1229 - accuracy: 0.8382
# Epoch 246/1500
# 52/52 [==============================] - 0s 4ms/step - loss: 0.1229 - accuracy: 0.8388
# Epoch 247/1500
# 52/52 [==============================] - 0s 3ms/step - loss: 0.1229 - accuracy: 0.8388
# Epoch 248/1500
# 52/52 [==============================] - 0s 3ms/step - loss: 0.1229 - accuracy: 0.8388
# Epoch 249/1500
# 52/52 [==============================] - 0s 3ms/step - loss: 0.1229 - accuracy: 0.8388
# Epoch 250/1500
# 52/52 [==============================] - 0s 3ms/step - loss: 0.1229 - accuracy: 0.8382
# Epoch 251/1500
# 52/52 [==============================] - 0s 4ms/step - loss: 0.1229 - accuracy: 0.8388
# Epoch 252/1500
# 52/52 [==============================] - 0s 3ms/step - loss: 0.1229 - accuracy: 0.8388
# Epoch 253/1500
# 52/52 [==============================] - 0s 3ms/step - loss: 0.1229 - accuracy: 0.8394
# Epoch 254/1500
# 52/52 [==============================] - 0s 3ms/step - loss: 0.1229 - accuracy: 0.8394
# Epoch 255/1500
# 52/52 [==============================] - 0s 3ms/step - loss: 0.1229 - accuracy: 0.8382
# Epoch 256/1500
# 52/52 [==============================] - 0s 3ms/step - loss: 0.1229 - accuracy: 0.8394
# Epoch 257/1500
# 52/52 [==============================] - 0s 3ms/step - loss: 0.1229 - accuracy: 0.8394
# Epoch 258/1500
# 52/52 [==============================] - 0s 4ms/step - loss: 0.1229 - accuracy: 0.8388
# Epoch 259/1500
# 52/52 [==============================] - 0s 3ms/step - loss: 0.1229 - accuracy: 0.8394
# Epoch 260/1500
# 52/52 [==============================] - 0s 3ms/step - loss: 0.1228 - accuracy: 0.8394
# Epoch 261/1500
# 52/52 [==============================] - 0s 3ms/step - loss: 0.1228 - accuracy: 0.8388
# Epoch 262/1500
# 52/52 [==============================] - 0s 3ms/step - loss: 0.1228 - accuracy: 0.8394
# Epoch 263/1500
# 52/52 [==============================] - 0s 3ms/step - loss: 0.1228 - accuracy: 0.8388
# Epoch 264/1500
# 52/52 [==============================] - 0s 4ms/step - loss: 0.1228 - accuracy: 0.8382
# Epoch 265/1500
# 52/52 [==============================] - 0s 3ms/step - loss: 0.1228 - accuracy: 0.8394
# Epoch 266/1500
# 52/52 [==============================] - 0s 3ms/step - loss: 0.1228 - accuracy: 0.8388
# Epoch 267/1500
# 52/52 [==============================] - 0s 3ms/step - loss: 0.1228 - accuracy: 0.8388
# Epoch 268/1500
# 52/52 [==============================] - 0s 3ms/step - loss: 0.1228 - accuracy: 0.8388
# Epoch 269/1500
# 52/52 [==============================] - 0s 3ms/step - loss: 0.1228 - accuracy: 0.8382
# Epoch 270/1500
# 52/52 [==============================] - 0s 3ms/step - loss: 0.1228 - accuracy: 0.8388
# Epoch 271/1500
# 52/52 [==============================] - 0s 4ms/step - loss: 0.1228 - accuracy: 0.8394
# Epoch 272/1500
# 52/52 [==============================] - 0s 3ms/step - loss: 0.1228 - accuracy: 0.8388
# Epoch 273/1500
# 52/52 [==============================] - 0s 4ms/step - loss: 0.1228 - accuracy: 0.8388
# Epoch 274/1500
# 52/52 [==============================] - 0s 3ms/step - loss: 0.1228 - accuracy: 0.8388
# Epoch 275/1500
# 52/52 [==============================] - 0s 3ms/step - loss: 0.1228 - accuracy: 0.8382
# Epoch 276/1500
# 52/52 [==============================] - 0s 3ms/step - loss: 0.1227 - accuracy: 0.8388
# Epoch 277/1500
# 52/52 [==============================] - 0s 4ms/step - loss: 0.1228 - accuracy: 0.8388
# Epoch 278/1500
# 52/52 [==============================] - 0s 4ms/step - loss: 0.1227 - accuracy: 0.8388
# Epoch 279/1500
# 52/52 [==============================] - 0s 3ms/step - loss: 0.1227 - accuracy: 0.8394
# Epoch 280/1500
# 52/52 [==============================] - 0s 3ms/step - loss: 0.1227 - accuracy: 0.8388
# Epoch 281/1500
# 52/52 [==============================] - 0s 3ms/step - loss: 0.1227 - accuracy: 0.8388
# Epoch 282/1500
# 52/52 [==============================] - 0s 4ms/step - loss: 0.1227 - accuracy: 0.8388
# Epoch 283/1500
# 52/52 [==============================] - 0s 3ms/step - loss: 0.1227 - accuracy: 0.8388
# Epoch 284/1500
# 52/52 [==============================] - 0s 4ms/step - loss: 0.1227 - accuracy: 0.8394
# Epoch 285/1500
# 52/52 [==============================] - 0s 3ms/step - loss: 0.1227 - accuracy: 0.8388
# Epoch 286/1500
# 52/52 [==============================] - 0s 3ms/step - loss: 0.1227 - accuracy: 0.8400
# Epoch 287/1500
# 52/52 [==============================] - 0s 3ms/step - loss: 0.1227 - accuracy: 0.8382
# Epoch 288/1500
# 52/52 [==============================] - 0s 3ms/step - loss: 0.1227 - accuracy: 0.8388
# Epoch 289/1500
# 52/52 [==============================] - 0s 3ms/step - loss: 0.1227 - accuracy: 0.8388
# Epoch 290/1500
# 52/52 [==============================] - 0s 3ms/step - loss: 0.1227 - accuracy: 0.8394
# Epoch 291/1500
# 52/52 [==============================] - 0s 4ms/step - loss: 0.1227 - accuracy: 0.8382
# Epoch 292/1500
# 52/52 [==============================] - 0s 3ms/step - loss: 0.1226 - accuracy: 0.8388
# Epoch 293/1500
# 52/52 [==============================] - 0s 3ms/step - loss: 0.1226 - accuracy: 0.8382
# Epoch 294/1500
# 52/52 [==============================] - 0s 3ms/step - loss: 0.1226 - accuracy: 0.8388
# Epoch 295/1500
# 52/52 [==============================] - 0s 3ms/step - loss: 0.1226 - accuracy: 0.8382
# Epoch 296/1500
# 52/52 [==============================] - 0s 3ms/step - loss: 0.1226 - accuracy: 0.8382
# Epoch 297/1500
# 52/52 [==============================] - 0s 4ms/step - loss: 0.1226 - accuracy: 0.8382
# Epoch 298/1500
# 52/52 [==============================] - 0s 3ms/step - loss: 0.1226 - accuracy: 0.8400
# Epoch 299/1500
# 52/52 [==============================] - 0s 3ms/step - loss: 0.1226 - accuracy: 0.8388
# Epoch 300/1500
# 52/52 [==============================] - 0s 3ms/step - loss: 0.1226 - accuracy: 0.8388
# Epoch 301/1500
# 52/52 [==============================] - 0s 3ms/step - loss: 0.1226 - accuracy: 0.8388
# Epoch 302/1500
# 52/52 [==============================] - 0s 4ms/step - loss: 0.1226 - accuracy: 0.8388
# Epoch 303/1500
# 52/52 [==============================] - 0s 3ms/step - loss: 0.1226 - accuracy: 0.8388
# Epoch 304/1500
# 52/52 [==============================] - 0s 4ms/step - loss: 0.1226 - accuracy: 0.8394
# Epoch 305/1500
# 52/52 [==============================] - 0s 3ms/step - loss: 0.1226 - accuracy: 0.8394
# Epoch 306/1500
# 52/52 [==============================] - 0s 3ms/step - loss: 0.1226 - accuracy: 0.8394
# Epoch 307/1500
# 52/52 [==============================] - 0s 3ms/step - loss: 0.1226 - accuracy: 0.8388
# Epoch 308/1500
# 52/52 [==============================] - 0s 4ms/step - loss: 0.1226 - accuracy: 0.8394
# Epoch 309/1500
# 52/52 [==============================] - 0s 4ms/step - loss: 0.1225 - accuracy: 0.8388
# Epoch 310/1500
# 52/52 [==============================] - 0s 4ms/step - loss: 0.1225 - accuracy: 0.8394
# Epoch 311/1500
# 52/52 [==============================] - 0s 4ms/step - loss: 0.1225 - accuracy: 0.8394
# Epoch 312/1500
# 52/52 [==============================] - 0s 3ms/step - loss: 0.1225 - accuracy: 0.8388
# Epoch 313/1500
# 52/52 [==============================] - 0s 3ms/step - loss: 0.1225 - accuracy: 0.8394
# Epoch 314/1500
# 52/52 [==============================] - 0s 3ms/step - loss: 0.1225 - accuracy: 0.8388
# Epoch 315/1500
# 52/52 [==============================] - 0s 3ms/step - loss: 0.1225 - accuracy: 0.8400
# Epoch 316/1500
# 52/52 [==============================] - 0s 4ms/step - loss: 0.1225 - accuracy: 0.8400
# Epoch 317/1500
# 52/52 [==============================] - 0s 4ms/step - loss: 0.1225 - accuracy: 0.8388
# Epoch 318/1500
# 52/52 [==============================] - 0s 3ms/step - loss: 0.1225 - accuracy: 0.8394
# Epoch 319/1500
# 52/52 [==============================] - 0s 4ms/step - loss: 0.1225 - accuracy: 0.8394
# Epoch 320/1500
# 52/52 [==============================] - 0s 4ms/step - loss: 0.1225 - accuracy: 0.8394
# Epoch 321/1500
# 52/52 [==============================] - 0s 5ms/step - loss: 0.1225 - accuracy: 0.8394
# Epoch 322/1500
# 52/52 [==============================] - 0s 3ms/step - loss: 0.1225 - accuracy: 0.8400
# Epoch 323/1500
# 52/52 [==============================] - 0s 3ms/step - loss: 0.1225 - accuracy: 0.8394
# Epoch 324/1500
# 52/52 [==============================] - 0s 3ms/step - loss: 0.1224 - accuracy: 0.8388
# Epoch 325/1500
# 52/52 [==============================] - 0s 4ms/step - loss: 0.1224 - accuracy: 0.8388
# Epoch 326/1500
# 52/52 [==============================] - 0s 4ms/step - loss: 0.1224 - accuracy: 0.8394
# Epoch 327/1500
# 52/52 [==============================] - 0s 4ms/step - loss: 0.1224 - accuracy: 0.8394
# Epoch 328/1500
# 52/52 [==============================] - 0s 3ms/step - loss: 0.1224 - accuracy: 0.8394
# Epoch 329/1500
# 52/52 [==============================] - 0s 3ms/step - loss: 0.1224 - accuracy: 0.8394
# Epoch 330/1500
# 52/52 [==============================] - 0s 3ms/step - loss: 0.1224 - accuracy: 0.8388
# Epoch 331/1500
# 52/52 [==============================] - 0s 3ms/step - loss: 0.1224 - accuracy: 0.8400
# Epoch 332/1500
# 52/52 [==============================] - 0s 4ms/step - loss: 0.1224 - accuracy: 0.8406
# Epoch 333/1500
# 52/52 [==============================] - 0s 4ms/step - loss: 0.1224 - accuracy: 0.8394
# Epoch 334/1500
# 52/52 [==============================] - 0s 3ms/step - loss: 0.1224 - accuracy: 0.8388
# Epoch 335/1500
# 52/52 [==============================] - 0s 3ms/step - loss: 0.1224 - accuracy: 0.8406
# Epoch 336/1500
# 52/52 [==============================] - 0s 3ms/step - loss: 0.1224 - accuracy: 0.8400
# Epoch 337/1500
# 52/52 [==============================] - 0s 3ms/step - loss: 0.1224 - accuracy: 0.8400
# Epoch 338/1500
# 52/52 [==============================] - 0s 3ms/step - loss: 0.1224 - accuracy: 0.8388
# Epoch 339/1500
# 52/52 [==============================] - 0s 4ms/step - loss: 0.1223 - accuracy: 0.8394
# Epoch 340/1500
# 52/52 [==============================] - 0s 3ms/step - loss: 0.1223 - accuracy: 0.8382
# Epoch 341/1500
# 52/52 [==============================] - 0s 3ms/step - loss: 0.1223 - accuracy: 0.8406
# Epoch 342/1500
# 52/52 [==============================] - 0s 4ms/step - loss: 0.1223 - accuracy: 0.8394
# Epoch 343/1500
# 52/52 [==============================] - 0s 3ms/step - loss: 0.1223 - accuracy: 0.8400
# Epoch 344/1500
# 52/52 [==============================] - 0s 4ms/step - loss: 0.1223 - accuracy: 0.8394
# Epoch 345/1500
# 52/52 [==============================] - 0s 4ms/step - loss: 0.1223 - accuracy: 0.8400
# Epoch 346/1500
# 52/52 [==============================] - 0s 3ms/step - loss: 0.1223 - accuracy: 0.8400
# Epoch 347/1500
# 52/52 [==============================] - 0s 3ms/step - loss: 0.1223 - accuracy: 0.8394
# Epoch 348/1500
# 52/52 [==============================] - 0s 3ms/step - loss: 0.1223 - accuracy: 0.8394
# Epoch 349/1500
# 52/52 [==============================] - 0s 3ms/step - loss: 0.1223 - accuracy: 0.8394
# Epoch 350/1500
# 52/52 [==============================] - 0s 4ms/step - loss: 0.1223 - accuracy: 0.8394
# Epoch 351/1500
# 52/52 [==============================] - 0s 4ms/step - loss: 0.1223 - accuracy: 0.8400
# Epoch 352/1500
# 52/52 [==============================] - 0s 3ms/step - loss: 0.1223 - accuracy: 0.8400
# Epoch 353/1500
# 52/52 [==============================] - 0s 3ms/step - loss: 0.1222 - accuracy: 0.8394
# Epoch 354/1500
# 52/52 [==============================] - 0s 3ms/step - loss: 0.1222 - accuracy: 0.8400
# Epoch 355/1500
# 52/52 [==============================] - 0s 4ms/step - loss: 0.1222 - accuracy: 0.8400
# Epoch 356/1500
# 52/52 [==============================] - 0s 4ms/step - loss: 0.1222 - accuracy: 0.8400
# Epoch 357/1500
# 52/52 [==============================] - 0s 5ms/step - loss: 0.1222 - accuracy: 0.8394
# Epoch 358/1500
# 52/52 [==============================] - 0s 4ms/step - loss: 0.1222 - accuracy: 0.8400
# Epoch 359/1500
# 52/52 [==============================] - 0s 4ms/step - loss: 0.1222 - accuracy: 0.8400
# Epoch 360/1500
# 52/52 [==============================] - 0s 4ms/step - loss: 0.1222 - accuracy: 0.8400
# Epoch 361/1500
# 52/52 [==============================] - 0s 4ms/step - loss: 0.1222 - accuracy: 0.8394
# Epoch 362/1500
# 52/52 [==============================] - 0s 4ms/step - loss: 0.1222 - accuracy: 0.8406
# Epoch 363/1500
# 52/52 [==============================] - 0s 4ms/step - loss: 0.1222 - accuracy: 0.8400
# Epoch 364/1500
# 52/52 [==============================] - 0s 4ms/step - loss: 0.1222 - accuracy: 0.8406
# Epoch 365/1500
# 52/52 [==============================] - 0s 4ms/step - loss: 0.1222 - accuracy: 0.8394
# Epoch 366/1500
# 52/52 [==============================] - 0s 4ms/step - loss: 0.1222 - accuracy: 0.8406
# Epoch 367/1500
# 52/52 [==============================] - 0s 4ms/step - loss: 0.1222 - accuracy: 0.8394
# Epoch 368/1500
# 52/52 [==============================] - 0s 5ms/step - loss: 0.1221 - accuracy: 0.8394
# Epoch 369/1500
# 52/52 [==============================] - 0s 4ms/step - loss: 0.1221 - accuracy: 0.8400
# Epoch 370/1500
# 52/52 [==============================] - 0s 4ms/step - loss: 0.1221 - accuracy: 0.8400
# Epoch 371/1500
# 52/52 [==============================] - 0s 4ms/step - loss: 0.1221 - accuracy: 0.8406
# Epoch 372/1500
# 52/52 [==============================] - 0s 5ms/step - loss: 0.1221 - accuracy: 0.8400
# Epoch 373/1500
# 52/52 [==============================] - 0s 4ms/step - loss: 0.1221 - accuracy: 0.8406
# Epoch 374/1500
# 52/52 [==============================] - 0s 4ms/step - loss: 0.1221 - accuracy: 0.8406
# Epoch 375/1500
# 52/52 [==============================] - 0s 4ms/step - loss: 0.1221 - accuracy: 0.8412
# Epoch 376/1500
# 52/52 [==============================] - 0s 4ms/step - loss: 0.1221 - accuracy: 0.8400
# Epoch 377/1500
# 52/52 [==============================] - 0s 4ms/step - loss: 0.1221 - accuracy: 0.8394
# Epoch 378/1500
# 52/52 [==============================] - 0s 4ms/step - loss: 0.1221 - accuracy: 0.8412
# Epoch 379/1500
# 52/52 [==============================] - 0s 4ms/step - loss: 0.1221 - accuracy: 0.8412
# Epoch 380/1500
# 52/52 [==============================] - 0s 4ms/step - loss: 0.1221 - accuracy: 0.8412
# Epoch 381/1500
# 52/52 [==============================] - 0s 4ms/step - loss: 0.1221 - accuracy: 0.8418
# Epoch 382/1500
# 52/52 [==============================] - 0s 4ms/step - loss: 0.1220 - accuracy: 0.8400
# Epoch 383/1500
# 52/52 [==============================] - 0s 4ms/step - loss: 0.1220 - accuracy: 0.8406
# Epoch 384/1500
# 52/52 [==============================] - 0s 4ms/step - loss: 0.1220 - accuracy: 0.8406
# Epoch 385/1500
# 52/52 [==============================] - 0s 4ms/step - loss: 0.1220 - accuracy: 0.8406
# Epoch 386/1500
# 52/52 [==============================] - 0s 4ms/step - loss: 0.1220 - accuracy: 0.8406
# Epoch 387/1500
# 52/52 [==============================] - 0s 4ms/step - loss: 0.1220 - accuracy: 0.8412
# Epoch 388/1500
# 52/52 [==============================] - 0s 4ms/step - loss: 0.1220 - accuracy: 0.8406
# Epoch 389/1500
# 52/52 [==============================] - 0s 4ms/step - loss: 0.1220 - accuracy: 0.8394
# Epoch 390/1500
# 52/52 [==============================] - 0s 4ms/step - loss: 0.1220 - accuracy: 0.8394
# Epoch 391/1500
# 52/52 [==============================] - 0s 4ms/step - loss: 0.1220 - accuracy: 0.8406
# Epoch 392/1500
# 52/52 [==============================] - 0s 4ms/step - loss: 0.1220 - accuracy: 0.8412
# Epoch 393/1500
# 52/52 [==============================] - 0s 4ms/step - loss: 0.1219 - accuracy: 0.8406
# Epoch 394/1500
# 52/52 [==============================] - 0s 4ms/step - loss: 0.1219 - accuracy: 0.8406
# Epoch 395/1500
# 52/52 [==============================] - 0s 5ms/step - loss: 0.1219 - accuracy: 0.8400
# Epoch 396/1500
# 52/52 [==============================] - 0s 4ms/step - loss: 0.1219 - accuracy: 0.8406
# Epoch 397/1500
# 52/52 [==============================] - 0s 4ms/step - loss: 0.1219 - accuracy: 0.8406
# Epoch 398/1500
# 52/52 [==============================] - 0s 4ms/step - loss: 0.1219 - accuracy: 0.8406
# Epoch 399/1500
# 52/52 [==============================] - 0s 4ms/step - loss: 0.1219 - accuracy: 0.8400
# Epoch 400/1500
# 52/52 [==============================] - 0s 4ms/step - loss: 0.1219 - accuracy: 0.8406
# Epoch 401/1500
# 52/52 [==============================] - 0s 4ms/step - loss: 0.1219 - accuracy: 0.8400
# Epoch 402/1500
# 52/52 [==============================] - 0s 4ms/step - loss: 0.1219 - accuracy: 0.8412
# Epoch 403/1500
# 52/52 [==============================] - 0s 4ms/step - loss: 0.1219 - accuracy: 0.8412
# Epoch 404/1500
# 52/52 [==============================] - 0s 4ms/step - loss: 0.1219 - accuracy: 0.8406
# Epoch 405/1500
# 52/52 [==============================] - 0s 4ms/step - loss: 0.1219 - accuracy: 0.8406
# Epoch 406/1500
# 52/52 [==============================] - 0s 4ms/step - loss: 0.1218 - accuracy: 0.8418
# Epoch 407/1500
# 52/52 [==============================] - 0s 4ms/step - loss: 0.1218 - accuracy: 0.8406
# Epoch 408/1500
# 52/52 [==============================] - 0s 4ms/step - loss: 0.1218 - accuracy: 0.8400
# Epoch 409/1500
# 52/52 [==============================] - 0s 4ms/step - loss: 0.1218 - accuracy: 0.8412
# Epoch 410/1500
# 52/52 [==============================] - 0s 4ms/step - loss: 0.1218 - accuracy: 0.8406
# Epoch 411/1500
# 52/52 [==============================] - 0s 4ms/step - loss: 0.1218 - accuracy: 0.8406
# Epoch 412/1500
# 52/52 [==============================] - 0s 5ms/step - loss: 0.1218 - accuracy: 0.8406
# Epoch 413/1500
# 52/52 [==============================] - 0s 4ms/step - loss: 0.1218 - accuracy: 0.8406
# Epoch 414/1500
# 52/52 [==============================] - 0s 4ms/step - loss: 0.1218 - accuracy: 0.8406
# Epoch 415/1500
# 52/52 [==============================] - 0s 4ms/step - loss: 0.1218 - accuracy: 0.8406
# Epoch 416/1500
# 52/52 [==============================] - 0s 4ms/step - loss: 0.1218 - accuracy: 0.8412
# Epoch 417/1500
# 52/52 [==============================] - 0s 4ms/step - loss: 0.1218 - accuracy: 0.8400
# Epoch 418/1500
# 52/52 [==============================] - 0s 5ms/step - loss: 0.1217 - accuracy: 0.8406
# Epoch 419/1500
# 52/52 [==============================] - 0s 4ms/step - loss: 0.1217 - accuracy: 0.8400
# Epoch 420/1500
# 52/52 [==============================] - 0s 4ms/step - loss: 0.1217 - accuracy: 0.8406
# Epoch 421/1500
# 52/52 [==============================] - 0s 4ms/step - loss: 0.1217 - accuracy: 0.8418
# Epoch 422/1500
# 52/52 [==============================] - 0s 4ms/step - loss: 0.1217 - accuracy: 0.8406
# Epoch 423/1500
# 52/52 [==============================] - 0s 5ms/step - loss: 0.1217 - accuracy: 0.8412
# Epoch 424/1500
# 52/52 [==============================] - 0s 4ms/step - loss: 0.1217 - accuracy: 0.8412
# Epoch 425/1500
# 52/52 [==============================] - 0s 4ms/step - loss: 0.1217 - accuracy: 0.8412
# Epoch 426/1500
# 52/52 [==============================] - 0s 4ms/step - loss: 0.1217 - accuracy: 0.8412
# Epoch 427/1500
# 52/52 [==============================] - 0s 4ms/step - loss: 0.1217 - accuracy: 0.8412
# Epoch 428/1500
# 52/52 [==============================] - 0s 5ms/step - loss: 0.1217 - accuracy: 0.8406
# Epoch 429/1500
# 52/52 [==============================] - 0s 5ms/step - loss: 0.1217 - accuracy: 0.8406
# Epoch 430/1500
# 52/52 [==============================] - 0s 4ms/step - loss: 0.1216 - accuracy: 0.8412
# Epoch 431/1500
# 52/52 [==============================] - 0s 4ms/step - loss: 0.1216 - accuracy: 0.8412
# Epoch 432/1500
# 52/52 [==============================] - 0s 4ms/step - loss: 0.1216 - accuracy: 0.8412
# Epoch 433/1500
# 52/52 [==============================] - 0s 4ms/step - loss: 0.1216 - accuracy: 0.8412
# Epoch 434/1500
# 52/52 [==============================] - 0s 4ms/step - loss: 0.1216 - accuracy: 0.8412
# Epoch 435/1500
# 52/52 [==============================] - 0s 4ms/step - loss: 0.1216 - accuracy: 0.8412
# Epoch 436/1500
# 52/52 [==============================] - 0s 4ms/step - loss: 0.1216 - accuracy: 0.8412
# Epoch 437/1500
# 52/52 [==============================] - 0s 4ms/step - loss: 0.1216 - accuracy: 0.8412
# Epoch 438/1500
# 52/52 [==============================] - 0s 4ms/step - loss: 0.1216 - accuracy: 0.8406
# Epoch 439/1500
# 52/52 [==============================] - 0s 4ms/step - loss: 0.1216 - accuracy: 0.8412
# Epoch 440/1500
# 52/52 [==============================] - 0s 4ms/step - loss: 0.1216 - accuracy: 0.8412
# Epoch 441/1500
# 52/52 [==============================] - 0s 4ms/step - loss: 0.1215 - accuracy: 0.8412
# Epoch 442/1500
# 52/52 [==============================] - 0s 4ms/step - loss: 0.1215 - accuracy: 0.8412
# Epoch 443/1500
# 52/52 [==============================] - 0s 4ms/step - loss: 0.1215 - accuracy: 0.8412
# Epoch 444/1500
# 52/52 [==============================] - 0s 4ms/step - loss: 0.1215 - accuracy: 0.8412
# Epoch 445/1500
# 52/52 [==============================] - 0s 4ms/step - loss: 0.1215 - accuracy: 0.8400
# Epoch 446/1500
# 52/52 [==============================] - 0s 4ms/step - loss: 0.1215 - accuracy: 0.8406
# Epoch 447/1500
# 52/52 [==============================] - 0s 4ms/step - loss: 0.1215 - accuracy: 0.8412
# Epoch 448/1500
# 52/52 [==============================] - 0s 4ms/step - loss: 0.1215 - accuracy: 0.8412
# Epoch 449/1500
# 52/52 [==============================] - 0s 4ms/step - loss: 0.1215 - accuracy: 0.8412
# Epoch 450/1500
# 52/52 [==============================] - 0s 4ms/step - loss: 0.1215 - accuracy: 0.8412
# Epoch 451/1500
# 52/52 [==============================] - 0s 4ms/step - loss: 0.1215 - accuracy: 0.8412
# Epoch 452/1500
# 52/52 [==============================] - 0s 4ms/step - loss: 0.1215 - accuracy: 0.8412
# Epoch 453/1500
# 52/52 [==============================] - 0s 4ms/step - loss: 0.1214 - accuracy: 0.8406
# Epoch 454/1500
# 52/52 [==============================] - 0s 4ms/step - loss: 0.1214 - accuracy: 0.8412
# Epoch 455/1500
# 52/52 [==============================] - 0s 4ms/step - loss: 0.1214 - accuracy: 0.8418
# Epoch 456/1500
# 52/52 [==============================] - 0s 4ms/step - loss: 0.1214 - accuracy: 0.8406
# Epoch 457/1500
# 52/52 [==============================] - 0s 4ms/step - loss: 0.1214 - accuracy: 0.8412
# Epoch 458/1500
# 52/52 [==============================] - 0s 4ms/step - loss: 0.1214 - accuracy: 0.8418
# Epoch 459/1500
# 52/52 [==============================] - 0s 5ms/step - loss: 0.1214 - accuracy: 0.8412
# Epoch 460/1500
# 52/52 [==============================] - 0s 5ms/step - loss: 0.1214 - accuracy: 0.8406
# Epoch 461/1500
# 52/52 [==============================] - 0s 4ms/step - loss: 0.1214 - accuracy: 0.8412
# Epoch 462/1500
# 52/52 [==============================] - 0s 4ms/step - loss: 0.1214 - accuracy: 0.8418
# Epoch 463/1500
# 52/52 [==============================] - 0s 4ms/step - loss: 0.1214 - accuracy: 0.8412
# Epoch 464/1500
# 52/52 [==============================] - 0s 4ms/step - loss: 0.1213 - accuracy: 0.8418
# Epoch 465/1500
# 52/52 [==============================] - 0s 4ms/step - loss: 0.1213 - accuracy: 0.8406
# Epoch 466/1500
# 52/52 [==============================] - 0s 5ms/step - loss: 0.1213 - accuracy: 0.8412
# Epoch 467/1500
# 52/52 [==============================] - 0s 4ms/step - loss: 0.1213 - accuracy: 0.8418
# Epoch 468/1500
# 52/52 [==============================] - 0s 4ms/step - loss: 0.1213 - accuracy: 0.8418
# Epoch 469/1500
# 52/52 [==============================] - 0s 4ms/step - loss: 0.1213 - accuracy: 0.8418
# Epoch 470/1500
# 52/52 [==============================] - 0s 4ms/step - loss: 0.1213 - accuracy: 0.8418
# Epoch 471/1500
# 52/52 [==============================] - 0s 4ms/step - loss: 0.1213 - accuracy: 0.8418
# Epoch 472/1500
# ...
# Epoch 1383/1500
# 52/52 [==============================] - 0s 4ms/step - loss: 0.0967 - accuracy: 0.8774
# Epoch 1384/1500
# 52/52 [==============================] - 0s 3ms/step - loss: 0.0967 - accuracy: 0.8780
# Epoch 1385/1500
# 52/52 [==============================] - 0s 3ms/step - loss: 0.0967 - accuracy: 0.8774
# Epoch 1386/1500
# 52/52 [==============================] - 0s 4ms/step - loss: 0.0966 - accuracy: 0.8768
# Epoch 1387/1500
# 52/52 [==============================] - 0s 3ms/step - loss: 0.0966 - accuracy: 0.8780
# Epoch 1388/1500
# 52/52 [==============================] - 0s 4ms/step - loss: 0.0966 - accuracy: 0.8774
# Epoch 1389/1500
# 52/52 [==============================] - 0s 3ms/step - loss: 0.0965 - accuracy: 0.8786
# Epoch 1390/1500
# 52/52 [==============================] - 0s 4ms/step - loss: 0.0965 - accuracy: 0.8780
# Epoch 1391/1500
# 52/52 [==============================] - 0s 3ms/step - loss: 0.0965 - accuracy: 0.8792
# Epoch 1392/1500
# 52/52 [==============================] - 0s 3ms/step - loss: 0.0965 - accuracy: 0.8792
# Epoch 1393/1500
# 52/52 [==============================] - 0s 3ms/step - loss: 0.0964 - accuracy: 0.8786
# Epoch 1394/1500
# 52/52 [==============================] - 0s 4ms/step - loss: 0.0964 - accuracy: 0.8792
# Epoch 1395/1500
# 52/52 [==============================] - 0s 3ms/step - loss: 0.0964 - accuracy: 0.8786
# Epoch 1396/1500
# 52/52 [==============================] - 0s 3ms/step - loss: 0.0963 - accuracy: 0.8786
# Epoch 1397/1500
# 52/52 [==============================] - 0s 4ms/step - loss: 0.0963 - accuracy: 0.8798
# Epoch 1398/1500
# 52/52 [==============================] - 0s 4ms/step - loss: 0.0963 - accuracy: 0.8786
# Epoch 1399/1500
# 52/52 [==============================] - 0s 4ms/step - loss: 0.0963 - accuracy: 0.8792
# Epoch 1400/1500
# 52/52 [==============================] - 0s 4ms/step - loss: 0.0962 - accuracy: 0.8792
# Epoch 1401/1500
# 52/52 [==============================] - 0s 5ms/step - loss: 0.0962 - accuracy: 0.8786
# Epoch 1402/1500
# 52/52 [==============================] - 0s 4ms/step - loss: 0.0962 - accuracy: 0.8786
# Epoch 1403/1500
# 52/52 [==============================] - 0s 4ms/step - loss: 0.0962 - accuracy: 0.8786
# Epoch 1404/1500
# 52/52 [==============================] - 0s 4ms/step - loss: 0.0961 - accuracy: 0.8786
# Epoch 1405/1500
# 52/52 [==============================] - 0s 4ms/step - loss: 0.0961 - accuracy: 0.8792
# Epoch 1406/1500
# 52/52 [==============================] - 0s 5ms/step - loss: 0.0961 - accuracy: 0.8792
# Epoch 1407/1500
# 52/52 [==============================] - 0s 4ms/step - loss: 0.0961 - accuracy: 0.8792
# Epoch 1408/1500
# 52/52 [==============================] - 0s 4ms/step - loss: 0.0960 - accuracy: 0.8792
# Epoch 1409/1500
# 52/52 [==============================] - 0s 4ms/step - loss: 0.0960 - accuracy: 0.8792
# Epoch 1410/1500
# 52/52 [==============================] - 0s 4ms/step - loss: 0.0960 - accuracy: 0.8792
# Epoch 1411/1500
# 52/52 [==============================] - 0s 4ms/step - loss: 0.0960 - accuracy: 0.8792
# Epoch 1412/1500
# 52/52 [==============================] - 0s 4ms/step - loss: 0.0959 - accuracy: 0.8786
# Epoch 1413/1500
# 52/52 [==============================] - 0s 4ms/step - loss: 0.0959 - accuracy: 0.8792
# Epoch 1414/1500
# 52/52 [==============================] - 0s 4ms/step - loss: 0.0959 - accuracy: 0.8792
# Epoch 1415/1500
# 52/52 [==============================] - 0s 4ms/step - loss: 0.0958 - accuracy: 0.8792
# Epoch 1416/1500
# 52/52 [==============================] - 0s 4ms/step - loss: 0.0958 - accuracy: 0.8792
# Epoch 1417/1500
# 52/52 [==============================] - 0s 4ms/step - loss: 0.0958 - accuracy: 0.8792
# Epoch 1418/1500
# 52/52 [==============================] - 0s 5ms/step - loss: 0.0958 - accuracy: 0.8792
# Epoch 1419/1500
# 52/52 [==============================] - 0s 4ms/step - loss: 0.0957 - accuracy: 0.8792
# Epoch 1420/1500
# 52/52 [==============================] - 0s 4ms/step - loss: 0.0957 - accuracy: 0.8792
# Epoch 1421/1500
# 52/52 [==============================] - 0s 4ms/step - loss: 0.0957 - accuracy: 0.8792
# Epoch 1422/1500
# 52/52 [==============================] - 0s 5ms/step - loss: 0.0957 - accuracy: 0.8792
# Epoch 1423/1500
# 52/52 [==============================] - 0s 4ms/step - loss: 0.0956 - accuracy: 0.8792
# Epoch 1424/1500
# 52/52 [==============================] - 0s 4ms/step - loss: 0.0956 - accuracy: 0.8792
# Epoch 1425/1500
# 52/52 [==============================] - 0s 5ms/step - loss: 0.0956 - accuracy: 0.8792
# Epoch 1426/1500
# 52/52 [==============================] - 0s 4ms/step - loss: 0.0956 - accuracy: 0.8792
# Epoch 1427/1500
# 52/52 [==============================] - 0s 4ms/step - loss: 0.0955 - accuracy: 0.8792
# Epoch 1428/1500
# 52/52 [==============================] - 0s 6ms/step - loss: 0.0955 - accuracy: 0.8792
# Epoch 1429/1500
# 52/52 [==============================] - 0s 5ms/step - loss: 0.0955 - accuracy: 0.8792
# Epoch 1430/1500
# 52/52 [==============================] - 0s 4ms/step - loss: 0.0955 - accuracy: 0.8792
# Epoch 1431/1500
# 52/52 [==============================] - 0s 4ms/step - loss: 0.0954 - accuracy: 0.8792
# Epoch 1432/1500
# 52/52 [==============================] - 0s 4ms/step - loss: 0.0954 - accuracy: 0.8792
# Epoch 1433/1500
# 52/52 [==============================] - 0s 4ms/step - loss: 0.0954 - accuracy: 0.8792
# Epoch 1434/1500
# 52/52 [==============================] - 0s 4ms/step - loss: 0.0954 - accuracy: 0.8792
# Epoch 1435/1500
# 52/52 [==============================] - 0s 4ms/step - loss: 0.0953 - accuracy: 0.8792
# Epoch 1436/1500
# 52/52 [==============================] - 0s 4ms/step - loss: 0.0953 - accuracy: 0.8798
# Epoch 1437/1500
# 52/52 [==============================] - 0s 4ms/step - loss: 0.0953 - accuracy: 0.8792
# Epoch 1438/1500
# 52/52 [==============================] - 0s 5ms/step - loss: 0.0952 - accuracy: 0.8792
# Epoch 1439/1500
# 52/52 [==============================] - 0s 5ms/step - loss: 0.0952 - accuracy: 0.8792
# Epoch 1440/1500
# 52/52 [==============================] - 0s 6ms/step - loss: 0.0952 - accuracy: 0.8786
# Epoch 1441/1500
# 52/52 [==============================] - 0s 6ms/step - loss: 0.0952 - accuracy: 0.8792
# Epoch 1442/1500
# 52/52 [==============================] - 0s 6ms/step - loss: 0.0951 - accuracy: 0.8792
# Epoch 1443/1500
# 52/52 [==============================] - 0s 5ms/step - loss: 0.0951 - accuracy: 0.8786
# Epoch 1444/1500
# 52/52 [==============================] - 0s 4ms/step - loss: 0.0951 - accuracy: 0.8798
# Epoch 1445/1500
# 52/52 [==============================] - 0s 5ms/step - loss: 0.0951 - accuracy: 0.8786
# Epoch 1446/1500
# 52/52 [==============================] - 0s 4ms/step - loss: 0.0950 - accuracy: 0.8792
# Epoch 1447/1500
# 52/52 [==============================] - 0s 4ms/step - loss: 0.0950 - accuracy: 0.8792
# Epoch 1448/1500
# 52/52 [==============================] - 0s 4ms/step - loss: 0.0950 - accuracy: 0.8792
# Epoch 1449/1500
# 52/52 [==============================] - 0s 4ms/step - loss: 0.0950 - accuracy: 0.8798
# Epoch 1450/1500
# 52/52 [==============================] - 0s 4ms/step - loss: 0.0949 - accuracy: 0.8798
# Epoch 1451/1500
# 52/52 [==============================] - 0s 4ms/step - loss: 0.0949 - accuracy: 0.8798
# Epoch 1452/1500
# 52/52 [==============================] - 0s 4ms/step - loss: 0.0949 - accuracy: 0.8798
# Epoch 1453/1500
# 52/52 [==============================] - 0s 5ms/step - loss: 0.0949 - accuracy: 0.8798
# Epoch 1454/1500
# 52/52 [==============================] - 0s 4ms/step - loss: 0.0948 - accuracy: 0.8798
# Epoch 1455/1500
# 52/52 [==============================] - 0s 4ms/step - loss: 0.0948 - accuracy: 0.8798
# Epoch 1456/1500
#  1/52 [..............................] - ETA: 0s - loss: 0.0806 - accuracy: 0.9062
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_32500\1583954079.py in <module>
#      43                   model__optimizer = optimezer_to_test  )
#      44 grid = GridSearchCV(estimator=model, param_grid=param_grid, cv=5)
# ---> 45 grid_result = grid.fit(X_transformado, Y) #, callbacks=[reduce_lr])
#      46 # summarize results
#      47 print("Best: %f using %s" % (grid_result.best_score_, grid_result.best_params_))
#
# c:\Users\belch\anaconda3\envs\tfd10\lib\site-packages\sklearn\model_selection\_search.py in fit(self, X, y, groups, **fit_params)
#     889                 return results
#     890
# --> 891             self._run_search(evaluate_candidates)
#     892
#     893             # multimetric is determined here because in the case of a callable
#
# c:\Users\belch\anaconda3\envs\tfd10\lib\site-packages\sklearn\model_selection\_search.py in _run_search(self, evaluate_candidates)
#    1390     def _run_search(self, evaluate_candidates):
#    1391         """Search all candidates in param_grid"""
# -> 1392         evaluate_candidates(ParameterGrid(self.param_grid))
#    1393
#    1394
#
# c:\Users\belch\anaconda3\envs\tfd10\lib\site-packages\sklearn\model_selection\_search.py in evaluate_candidates(candidate_params, cv, more_results)
#     849                     )
#     850                     for (cand_idx, parameters), (split_idx, (train, test)) in product(
# --> 851                         enumerate(candidate_params), enumerate(cv.split(X, y, groups))
#     852                     )
#     853                 )
#
# c:\Users\belch\anaconda3\envs\tfd10\lib\site-packages\joblib\parallel.py in __call__(self, iterable)
#    1861             output = self._get_sequential_output(iterable)
#    1862             next(output)
# -> 1863             return output if self.return_generator else list(output)
#    1864
#    1865         # Let's create an ID that uniquely identifies the current call. If the
#
# c:\Users\belch\anaconda3\envs\tfd10\lib\site-packages\joblib\parallel.py in _get_sequential_output(self, iterable)
#    1790                 self.n_dispatched_batches += 1
#    1791                 self.n_dispatched_tasks += 1
# -> 1792                 res = func(*args, **kwargs)
#    1793                 self.n_completed_tasks += 1
#    1794                 self.print_progress()
#
# c:\Users\belch\anaconda3\envs\tfd10\lib\site-packages\sklearn\utils\fixes.py in __call__(self, *args, **kwargs)
#     214     def __call__(self, *args, **kwargs):
#     215         with config_context(**self.config):
# --> 216             return self.function(*args, **kwargs)
#     217
#     218
#
# c:\Users\belch\anaconda3\envs\tfd10\lib\site-packages\sklearn\model_selection\_validation.py in _fit_and_score(estimator, X, y, scorer, train, test, verbose, parameters, fit_params, return_train_score, return_parameters, return_n_test_samples, return_times, return_estimator, split_progress, candidate_progress, error_score)
#     678             estimator.fit(X_train, **fit_params)
#     679         else:
# --> 680             estimator.fit(X_train, y_train, **fit_params)
#     681
#     682     except Exception:
#
# c:\Users\belch\anaconda3\envs\tfd10\lib\site-packages\scikeras\wrappers.py in fit(self, X, y, sample_weight, **kwargs)
#    1492             sample_weight = 1 if sample_weight is None else sample_weight
#    1493             sample_weight *= compute_sample_weight(class_weight=self.class_weight, y=y)
# -> 1494         super().fit(X=X, y=y, sample_weight=sample_weight, **kwargs)
#    1495         return self
#    1496
#
# c:\Users\belch\anaconda3\envs\tfd10\lib\site-packages\scikeras\wrappers.py in fit(self, X, y, sample_weight, **kwargs)
#     765             sample_weight=sample_weight,
#     766             warm_start=self.warm_start,
# --> 767             **kwargs,
#     768         )
#     769
#
# c:\Users\belch\anaconda3\envs\tfd10\lib\site-packages\scikeras\wrappers.py in _fit(self, X, y, sample_weight, warm_start, epochs, initial_epoch, **kwargs)
#     936             epochs=epochs,
#     937             initial_epoch=initial_epoch,
# --> 938             **kwargs,
#     939         )
#     940
#
# c:\Users\belch\anaconda3\envs\tfd10\lib\site-packages\scikeras\wrappers.py in _fit_keras_model(self, X, y, sample_weight, warm_start, epochs, initial_epoch, **kwargs)
#     524                 hist = self.model_.fit(x=X, y=y, **fit_args)
#     525         else:
# --> 526             hist = self.model_.fit(x=X, y=y, **fit_args)
#     527
#     528         if not warm_start or not hasattr(self, "history_") or initial_epoch == 0:
#
# c:\Users\belch\anaconda3\envs\tfd10\lib\site-packages\keras\utils\traceback_utils.py in error_handler(*args, **kwargs)
#      63         filtered_tb = None
#      64         try:
# ---> 65             return fn(*args, **kwargs)
#      66         except Exception as e:
#      67             filtered_tb = _process_traceback_frames(e.__traceback__)
#
# c:\Users\belch\anaconda3\envs\tfd10\lib\site-packages\keras\engine\training.py in fit(self, x, y, batch_size, epochs, verbose, callbacks, validation_split, validation_data, shuffle, class_weight, sample_weight, initial_epoch, steps_per_epoch, validation_steps, validation_batch_size, validation_freq, max_queue_size, workers, use_multiprocessing)
#    1562                         ):
#    1563                             callbacks.on_train_batch_begin(step)
# -> 1564                             tmp_logs = self.train_function(iterator)
#    1565                             if data_handler.should_sync:
#    1566                                 context.async_wait()
#
# ~\AppData\Roaming\Python\Python37\site-packages\tensorflow\python\util\traceback_utils.py in error_handler(*args, **kwargs)
#     148     filtered_tb = None
#     149     try:
# --> 150       return fn(*args, **kwargs)
#     151     except Exception as e:
#     152       filtered_tb = _process_traceback_frames(e.__traceback__)
#
# ~\AppData\Roaming\Python\Python37\site-packages\tensorflow\python\eager\def_function.py in __call__(self, *args, **kwds)
#     913
#     914       with OptionalXlaContext(self._jit_compile):
# --> 915         result = self._call(*args, **kwds)
#     916
#     917       new_tracing_count = self.experimental_get_tracing_count()
#
# ~\AppData\Roaming\Python\Python37\site-packages\tensorflow\python\eager\def_function.py in _call(self, *args, **kwds)
#     945       # In this case we have created variables on the first call, so we run the
#     946       # defunned version which is guaranteed to never create variables.
# --> 947       return self._stateless_fn(*args, **kwds)  # pylint: disable=not-callable
#     948     elif self._stateful_fn is not None:
#     949       # Release the lock early so that multiple threads can perform the call
#
# ~\AppData\Roaming\Python\Python37\site-packages\tensorflow\python\eager\function.py in __call__(self, *args, **kwargs)
#    2495        filtered_flat_args) = self._maybe_define_function(args, kwargs)
#    2496     return graph_function._call_flat(
# -> 2497         filtered_flat_args, captured_inputs=graph_function.captured_inputs)  # pylint: disable=protected-access
#    2498
#    2499   @property
#
# ~\AppData\Roaming\Python\Python37\site-packages\tensorflow\python\eager\function.py in _call_flat(self, args, captured_inputs, cancellation_manager)
#    1861       # No tape is watching; skip to running the function.
#    1862       return self._build_call_outputs(self._inference_function.call(
# -> 1863           ctx, args, cancellation_manager=cancellation_manager))
#    1864     forward_backward = self._select_forward_and_backward_functions(
#    1865         args,
#
# ~\AppData\Roaming\Python\Python37\site-packages\tensorflow\python\eager\function.py in call(self, ctx, args, cancellation_manager)
#     502               inputs=args,
#     503               attrs=attrs,
# --> 504               ctx=ctx)
#     505         else:
#     506           outputs = execute.execute_with_cancellation(
#
# ~\AppData\Roaming\Python\Python37\site-packages\tensorflow\python\eager\execute.py in quick_execute(op_name, num_outputs, inputs, attrs, ctx, name)
#      53     ctx.ensure_initialized()
#      54     tensors = pywrap_tfe.TFE_Py_Execute(ctx._handle, device_name, op_name,
# ---> 55                                         inputs, attrs, num_outputs)
#      56   except core._NotOkStatusException as e:
#      57     if name is not None:
#
# KeyboardInterrupt:

# %%
from matplotlib import pyplot

# PLOT TRAINING HISTORY
fig = pyplot.figure(figsize=(12, 6))
ax = fig.add_subplot(111)
_ = ax.plot(grid_result.best_estimator_.history_['loss'], label='loss')
_ = ax.plot(grid_result.best_estimator_.history_['val_loss'], label='val_loss')
_ = ax.grid(which='major', linestyle='--', linewidth='0.5', color='gray')

# %%
len(X_transformado)
# Out:
# 2070

# %%
TesteEntrada= [[3,14,31.70,54,50,1,0,0]]
np_teste  = numpy.array(TesteEntrada)

resultt = grid_result.best_estimator_.predict(np_teste)
resultt
# Out:
# array([1], dtype=int64)

# %%
win_model = grid_result.best_estimator_.model_

model_json = win_model.to_json()
with open("model/model.json", "w") as json_file:
    json_file.write(model_json)

#salvando os pesos aprendidos pela rede neural
win_model.save_weights("model/weights.h5")

# %%
Y_est = grid_result.best_estimator_.predict(X_transformado, verbose=0)
relevance_dict = {}
df_X = recrutamento[features]
n_features_relevantes = 3

for feature in features:
    X_relevance = numpy.copy(X_transformado)
    X_relevance[:, df_X.columns == feature] = 0.0
    Y_est_relevance = grid_result.best_estimator_.predict(X_relevance, verbose=0)
    Y_relevance = (Y_est - Y_est_relevance)**2
    feature_relevance = Y_relevance.sum()/Y_relevance.shape[0]
    relevance_dict[feature] = feature_relevance
s_relevance = pd.Series(relevance_dict)
s_relevance_norm = s_relevance/s_relevance.max()
s_relevance_norm = s_relevance_norm.sort_values(ascending=False).head(n_features_relevantes)
selected_features = list(s_relevance_norm.index.values)
selected_relevance = list(100.0*s_relevance_norm.values)
df_relevance = pd.DataFrame({'feature': selected_features, 'relevance': selected_relevance})

# %%
df_relevance
# Out:
#                  feature   relevance
# 0  RecruitmentStrategy_1  100.000000
# 1       PersonalityScore   34.685315
# 2         EducationLevel   25.594406

# %%
X_relevant = df_X[selected_features].to_numpy()

# %%
Y_relevant = recrutamento[classificacao].to_numpy()

# %%
from imblearn.over_sampling import SMOTE
oversample = SMOTE()
X_relevant, Y_relevant = oversample.fit_resample(X_relevant, Y_relevant)

# %%
import matplotlib.pyplot as plt
STANDARD_SCALER = StandardScaler()
X_normalizado_standard = STANDARD_SCALER.fit_transform(X_relevant)


MIN_MAX_SCALER = MinMaxScaler(feature_range=(0, 1))
X_normalizado_min_max = MIN_MAX_SCALER.fit_transform(X_relevant)




from sklearn.preprocessing import PowerTransformer, QuantileTransformer

qt = QuantileTransformer(output_distribution='normal')


pt = PowerTransformer(method='yeo-johnson')


teste_yeo_johnson = pt.fit_transform(X_relevant)
teste_yeo_johnson = STANDARD_SCALER.fit_transform(teste_yeo_johnson)

teste_quantile = qt.fit_transform(X_relevant)
teste_quantile = STANDARD_SCALER.fit_transform(teste_quantile)


f, axs = plt.subplots(1, 5, figsize=(8, 4))
seaborn.kdeplot(X, ax=axs[0], legend=False,)
axs[0].set_title('Original', size=10)

seaborn.kdeplot(X_normalizado_standard, ax=axs[1], legend=False,)
axs[1].set_title('StandardScaler', size=10)

seaborn.kdeplot(X_normalizado_min_max, ax=axs[2], legend=False,)
axs[2].set_title('MinMAX', size=10)


seaborn.kdeplot(teste_yeo_johnson, ax=axs[3], legend=False)
axs[3].set_title('Yeo Johnson', size=10)

seaborn.kdeplot(teste_quantile, ax=axs[4], legend=False)
axs[4].set_title('Quantile', size=10)

f.tight_layout()

X_relevante_transformado = teste_quantile

# %%
#Testando com KerasClassifier
def create_model(neurons, activation, hidden_layers, loss_function, optimizer):
    # inputs = tf.keras.Input(shape=(X_transformado.shape[1],))
    # hidden = tf.keras.layers.Dense(neurons, activation=activation)(inputs)
    # hidden = tf.keras.layers.BatchNormalization()(hidden)
    # hidden = tf.keras.layers.Dense(neurons, activation=activation)(hidden)
    # hidden = tf.keras.layers.BatchNormalization()(hidden)

    model = tf.keras.models.Sequential()
    for layer in range(hidden_layers): 
        model.add(tf.keras.layers.Dense(neurons, input_shape=(X_relevante_transformado.shape[1],),  activation=activation))
        model.add(tf.keras.layers.BatchNormalization())
    
    model.add(tf.keras.layers.Dense(1, activation=Activation.SIGMOID.value))

    model.compile(loss=loss_function, optimizer=optimizer, metrics=[Metrics.ACCURACY.value])
    return model

funcoes_ativacao = [Activation.TANH.value ]#, Activation.RELU.value] 
metrica = Metrics.ACCURACY.value
# SEED que controla a aleatoriedade 
random_seed = 22
tf.random.set_seed(random_seed)
# create model
model = KerasClassifier(model=create_model,batch_size=-1, verbose=0)
# define the grid search parameters
neurons = [16, 24] 
hidden_layers =[1, 2, 3] 
loss_function=[LossFunction.MSE.value]
optimezer_to_test= [Optimizer.ADAM.value]
param_grid = dict(epochs=[1500], model__neurons=neurons, model__activation=funcoes_ativacao,
                  model__hidden_layers= hidden_layers, model__loss_function= loss_function,
                  model__optimizer = optimezer_to_test  )
grid = GridSearchCV(estimator=model, param_grid=param_grid, cv=5)
grid_result = grid.fit(X_relevant, Y_relevant)
# summarize results
print("Best: %f using %s" % (grid_result.best_score_, grid_result.best_params_))
means = grid_result.cv_results_['mean_test_score']
stds = grid_result.cv_results_['std_test_score']
params = grid_result.cv_results_['params']
for mean, stdev, param in zip(means, stds, params):
    print("%f (%f) with: %r" % (mean, stdev, param))
# Out:
# WARNING:tensorflow:5 out of the last 17 calls to <function Model.make_predict_function.<locals>.predict_function at 0x000002259119EDC8> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has reduce_retracing=True option that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# WARNING:tensorflow:6 out of the last 18 calls to <function Model.make_predict_function.<locals>.predict_function at 0x00000225B48BC1F8> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has reduce_retracing=True option that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# Best: 0.839614 using {'epochs': 1500, 'model__activation': 'tanh', 'model__hidden_layers': 3, 'model__loss_function': 'mse', 'model__neurons': 16, 'model__optimizer': 'adam'}
# 0.831884 (0.018995) with: {'epochs': 1500, 'model__activation': 'tanh', 'model__hidden_layers': 1, 'model__loss_function': 'mse', 'model__neurons': 16, 'model__optimizer': 'adam'}
# 0.833816 (0.017842) with: {'epochs': 1500, 'model__activation': 'tanh', 'model__hidden_layers': 1, 'model__loss_function': 'mse', 'model__neurons': 24, 'model__optimizer': 'adam'}
# 0.777295 (0.096684) with: {'epochs': 1500, 'model__activation': 'tanh', 'model__hidden_layers': 2, 'model__loss_function': 'mse', 'model__neurons': 16, 'model__optimizer': 'adam'}
# 0.743478 (0.090667) with: {'epochs': 1500, 'model__activation': 'tanh', 'model__hidden_layers': 2, 'model__loss_function': 'mse', 'model__neurons': 24, 'model__optimizer': 'adam'}
# 0.839614 (0.021091) with: {'epochs': 1500, 'model__activation': 'tanh', 'model__hidden_layers': 3, 'model__loss_function': 'mse', 'model__neurons': 16, 'model__optimizer': 'adam'}
# 0.808213 (0.047299) with: {'epochs': 1500, 'model__activation': 'tanh', 'model__hidden_layers': 3, 'model__loss_function': 'mse', 'model__neurons': 24, 'model__optimizer': 'adam'}

# %%
from sklearn.model_selection import train_test_split
X_treinamento, X_teste, y_treinamento, y_teste = train_test_split(X_transformado,
                                                                  Y,
                                                                  test_size = 0.3,
                                                                  random_state = 0)

y_predict = grid_result.best_estimator_.predict(X_teste)

from sklearn.metrics import ConfusionMatrixDisplay
fig = ConfusionMatrixDisplay.from_predictions(y_teste, y_predict , display_labels=['Not Hired', 'Hired'], cmap='Greens')
plt.title(grid_result.best_params_)
plt.show()

# %%
from sklearn.metrics import RocCurveDisplay
from matplotlib import pyplot

fig = pyplot.figure(figsize=(7, 7))
ax = fig.add_subplot(1, 1, 1)
_ = RocCurveDisplay.from_predictions(y_teste, y_predict, ax=ax)
_ = ax.grid(alpha=0.5, ls=':')

# %%
#IMPLEMENTANDO O RANDOMFOREST SEM BALANCEAMENTO
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import LabelEncoder
from sklearn.metrics import confusion_matrix
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score, roc_auc_score, confusion_matrix
from sklearn.metrics import ConfusionMatrixDisplay


# Divisão da base de dados entre treinamento e teste (30% para testar e 70% para treinar)
X_treinamento, X_teste, y_treinamento, y_teste = train_test_split(X_transformado,
                                                                  Y,
                                                                  test_size = 0.3,
                                                                  random_state = 0)
# Criação do modelo e treinamento
# Funciona por meio de votação, ou seja, a classe que tiver mais votos é a classe que o modelo vai escolher
floresta = RandomForestClassifier(n_estimators = 100)
floresta.fit(X_treinamento, y_treinamento)

previsoes = floresta.predict(X_teste)

# Os valores percentuais da previsão
# predict_proba retorna a probabilidade de cada classe, o primeiro valor é a probabilidade de ser 0 e o segundo de ser 1
previsoes_percent = floresta.predict_proba(X_teste)
# As probabilidades de 1, usaremos para a função ROC
previsoes_percent = previsoes_percent[:,1]
previsoes_percent


matriz_confusao = confusion_matrix(y_teste, previsoes)
matriz_confusao

# Acurácia
accuracy = accuracy_score(y_teste, previsoes)
print("Acurácia:", accuracy)

# Precisão
precision = precision_score(y_teste, previsoes)
print("Precisão:", precision)

# Recall
recall = recall_score(y_teste, previsoes)
print("Recall:", recall)

# Especificidade.
tn, fp, fn, tp = confusion_matrix(y_teste, previsoes).ravel()
specificity = tn / (tn + fp)
print("Especificidade:", specificity)

# F1 Score
f1 = f1_score(y_teste, previsoes)
print("F1 Score:", f1)

# ROC AUC Score (necessita das probabilidades de classe em vez de previsões).
# Para calcular a ROC AUC é necessário passar a probabilidade de ser 1.
roc_auc = roc_auc_score(y_teste, previsoes_percent)
print("ROC AUC Score:", roc_auc)

fig = ConfusionMatrixDisplay.from_estimator(floresta, X_teste, y_teste, display_labels=['Not Hired', 'Hired'], cmap='Greens')
plt.title('Standard Random Forest Confusion Matrix')
plt.show()
# Out:
# Acurácia: 0.9420289855072463
# Precisão: 0.9503311258278145
# Recall: 0.9318181818181818
# Especificidade: 0.952076677316294
# F1 Score: 0.940983606557377
# ROC AUC Score: 0.9728849425335048

# %%
# TREINANDO





####### GRID SEARCH QUE FAZ O LOOP 
maximo_neuronios = 5
#quantidade de loops q vai esperar ate q o erro de teste comece a aumentar 
paciencia = 150
max_epocas =3*paciencia
min_improvement = 0.01
adam_initial_lr = 0.01
adam_lr_decay = 0.99
rollback_on_no_lower_bound_gain = True #se comecar o erro a subir, volta pra onde tava bom


n_k_folds = 5 #quantas partes o dataset vai ser dividido

tf.random.set_seed(random_seed)
#keras.utils.set_random_seed(random_seed)
# DIVIDE EM K PEDACOS
sk_folds = StratifiedKFold(n_splits=n_k_folds)
sk_folds.get_n_splits(X_transformado, Y)

metric_lower_bound = 0.0
metric_median = 0.0
resultados = []
for n_neuron in numpy.arange(1, maximo_neuronios+1):
    ix_fold = 1
    #divisao os grupos de treino e teste, ele faz pelos indices
    for train_index, test_index in sk_folds.split(X_transformado, Y):
        # pegar o dado do teste  e treino   a partir dos indices da divisao feita pelo skfolds
        X_train, X_test = X_transformado[train_index], X_transformado[test_index]
        Y_train, Y_test = Y[train_index], Y[test_index]
        
        for funcao_ativacao in funcoes_ativacao : 
            #configurando o otimizador 
            optimizer = tf.keras.optimizers.Adam( learning_rate=adam_initial_lr, 
                                                    beta_1=adam_lr_decay ) 
            
            # Configurando a rede
            model_name = f"ADAM-N{n_neuron}F{ix_fold}_{classificacao}_{funcao_ativacao}"
            val_metric_name = f'val_{metrica}'
            
            inputs = tf.keras.Input(shape=(X_transformado.shape[1], ))        
            hidden = tf.keras.layers.Dense(n_neuron, activation=funcao_ativacao)(inputs)
            outputs = tf.keras.layers.Dense(1, activation='sigmoid')(hidden) #penas 1 classificacao = 1 saida
            rede = tf.keras.Model(inputs=inputs, outputs=outputs, name=model_name)

            #Usar o otimizador com erro medio quadratico 
            rede.compile(optimizer=optimizer, loss='mse', metrics=[metrica])
            
            #early stop com foco no erro do grupo de validacao
            es_loss = tf.keras.callbacks.EarlyStopping(monitor='val_loss', patience=paciencia, restore_best_weights=True)
            #early stop com foco na acuracia dos testes
            es_metric = tf.keras.callbacks.EarlyStopping(monitor=metrica, mode='max', patience=paciencia, min_delta=min_improvement, restore_best_weights=True)


            #iniciando a rede para tentar encontrar o modelo
            resultado = rede.fit(X_train, Y_train, validation_data=(X_test, Y_test), batch_size=X_train.shape[0], 
                                    epochs=max_epocas, verbose=0, callbacks=[es_loss, es_metric], )

        

            # RESULTADOS DA REDE
            model_loss = resultado.history['loss'][-1]
            model_val_loss = resultado.history['val_loss'][-1]
            metric_val = resultado.history[metrica][-1]
            val_metric_val = resultado.history[val_metric_name][-1]
            n_epochs = len(resultado.history['val_loss'])

            resultado_dict = {'model_name': model_name,
                            'optimizer': optimizer,
                            'neurons': n_neuron,
                            'fold': ix_fold,
                            'loss': model_loss,
                            'val_loss': model_val_loss,
                            metrica: metric_val,
                            val_metric_name: val_metric_val,
                            'epochs': n_epochs,
                            'net': rede,
                            'history': resultado}
            resultados.append(resultado_dict)

            print(f"{model_name} > epochs: {n_epochs} loss: {model_loss} val_loss: {model_val_loss} {metrica}: {100.0*metric_val}% {val_metric_name}: {100.0*val_metric_val}%")
                

            # SE CHEGAR NO 100% para de aumentar 
            maximized_metrics = (val_metric_val == 1.0) & (metric_val == 1.0)

            if maximized_metrics:
                break

            print('')
        ix_fold += 1
        
    # GET LOWER BOUND OF WINNING ALGORITHM
    df_resultados = pd.DataFrame(resultados)
# Out:
# ADAM-N1F1_HiringDecision_tanh > epochs: 317 loss: 0.12350894510746002 val_loss: 0.12206868082284927 Accuracy: 84.29951667785645% val_Accuracy: 84.29951667785645%
#
# ADAM-N1F1_HiringDecision_relu > epochs: 445 loss: 0.12401490658521652 val_loss: 0.1286454200744629 Accuracy: 84.3599021434784% val_Accuracy: 83.09178948402405%
#
# ADAM-N1F2_HiringDecision_tanh > epochs: 206 loss: 0.12897154688835144 val_loss: 0.10528505593538284 Accuracy: 83.27294588088989% val_Accuracy: 87.19806671142578%
#
# ADAM-N1F2_HiringDecision_relu > epochs: 413 loss: 0.12646572291851044 val_loss: 0.11069495975971222 Accuracy: 84.17874574661255% val_Accuracy: 85.26570200920105%
#
# ADAM-N1F3_HiringDecision_tanh > epochs: 237 loss: 0.11758480966091156 val_loss: 0.1606757789850235 Accuracy: 84.54106450080872% val_Accuracy: 80.67632913589478%
#
# ADAM-N1F3_HiringDecision_relu > epochs: 247 loss: 0.11706136912107468 val_loss: 0.162090003490448 Accuracy: 84.78260636329651% val_Accuracy: 80.91787695884705%
#
# ADAM-N1F4_HiringDecision_tanh > epochs: 285 loss: 0.1293489784002304 val_loss: 0.11431160569190979 Accuracy: 83.45410823822021% val_Accuracy: 84.78260636329651%
#
# ADAM-N1F4_HiringDecision_relu > epochs: 439 loss: 0.1322387158870697 val_loss: 0.11258939653635025 Accuracy: 83.39372277259827% val_Accuracy: 85.50724387168884%
#
# ADAM-N1F5_HiringDecision_tanh > epochs: 342 loss: 0.12312335520982742 val_loss: 0.1456264704465866 Accuracy: 84.66183543205261% val_Accuracy: 81.88405632972717%
#
# ADAM-N1F5_HiringDecision_relu > epochs: 450 loss: 0.12568914890289307 val_loss: 0.15354610979557037 Accuracy: 84.66183543205261% val_Accuracy: 81.15941882133484%
#
# ADAM-N2F1_HiringDecision_tanh > epochs: 285 loss: 0.11990179866552353 val_loss: 0.1278405487537384 Accuracy: 84.72222089767456% val_Accuracy: 83.33333134651184%
#
# ADAM-N2F1_HiringDecision_relu > epochs: 217 loss: 0.12562550604343414 val_loss: 0.12710906565189362 Accuracy: 83.93719792366028% val_Accuracy: 84.29951667785645%
#
# ADAM-N2F2_HiringDecision_tanh > epochs: 332 loss: 0.1182602122426033 val_loss: 0.10371227562427521 Accuracy: 83.93719792366028% val_Accuracy: 86.47342920303345%
#
# ADAM-N2F2_HiringDecision_relu > epochs: 260 loss: 0.13263839483261108 val_loss: 0.10764705389738083 Accuracy: 83.63526463508606% val_Accuracy: 85.99033951759338%
#
# ADAM-N2F3_HiringDecision_tanh > epochs: 237 loss: 0.11278906464576721 val_loss: 0.16564121842384338 Accuracy: 84.60144996643066% val_Accuracy: 79.46860194206238%
#
# ADAM-N2F3_HiringDecision_relu > epochs: 224 loss: 0.11448715627193451 val_loss: 0.16170616447925568 Accuracy: 84.66183543205261% val_Accuracy: 81.40096664428711%
#
# ADAM-N2F4_HiringDecision_tanh > epochs: 322 loss: 0.1286804974079132 val_loss: 0.11487317830324173 Accuracy: 83.33333134651184% val_Accuracy: 84.54106450080872%
#
# ADAM-N2F4_HiringDecision_relu > epochs: 272 loss: 0.12927427887916565 val_loss: 0.1153094694018364 Accuracy: 83.21256041526794% val_Accuracy: 85.26570200920105%
#
# ADAM-N2F5_HiringDecision_tanh > epochs: 228 loss: 0.11362820118665695 val_loss: 0.12070230394601822 Accuracy: 84.90338325500488% val_Accuracy: 81.88405632972717%
#
# ADAM-N2F5_HiringDecision_relu > epochs: 314 loss: 0.12611013650894165 val_loss: 0.15445199608802795 Accuracy: 84.54106450080872% val_Accuracy: 82.12560415267944%
#
# ADAM-N3F1_HiringDecision_tanh > epochs: 396 loss: 0.10433030873537064 val_loss: 0.11697313189506531 Accuracy: 85.74879169464111% val_Accuracy: 83.09178948402405%
#
# ADAM-N3F1_HiringDecision_relu > epochs: 237 loss: 0.11674373596906662 val_loss: 0.1242264062166214 Accuracy: 85.38647294044495% val_Accuracy: 83.33333134651184%
#
# ADAM-N3F2_HiringDecision_tanh > epochs: 251 loss: 0.12023631483316422 val_loss: 0.10670585185289383 Accuracy: 84.78260636329651% val_Accuracy: 86.71497702598572%
#
# ADAM-N3F2_HiringDecision_relu > epochs: 387 loss: 0.11581257730722427 val_loss: 0.10117698460817337 Accuracy: 84.29951667785645% val_Accuracy: 86.23188138008118%
#
# ADAM-N3F3_HiringDecision_tanh > epochs: 300 loss: 0.11253944784402847 val_loss: 0.1613749861717224 Accuracy: 85.4468584060669% val_Accuracy: 80.19323945045471%
#
# ADAM-N3F3_HiringDecision_relu > epochs: 240 loss: 0.10738543421030045 val_loss: 0.1598726361989975 Accuracy: 85.326087474823% val_Accuracy: 79.71014380455017%
#
# ADAM-N3F4_HiringDecision_tanh > epochs: 314 loss: 0.12241455912590027 val_loss: 0.09378063678741455 Accuracy: 83.21256041526794% val_Accuracy: 85.50724387168884%
#
# ADAM-N3F4_HiringDecision_relu > epochs: 321 loss: 0.1255161017179489 val_loss: 0.10762648284435272 Accuracy: 83.27294588088989% val_Accuracy: 85.50724387168884%
#
# ADAM-N3F5_HiringDecision_tanh > epochs: 232 loss: 0.1169797033071518 val_loss: 0.1359931081533432 Accuracy: 84.84299778938293% val_Accuracy: 82.12560415267944%
#
# ADAM-N3F5_HiringDecision_relu > epochs: 265 loss: 0.11743855476379395 val_loss: 0.12851856648921967 Accuracy: 84.96376872062683% val_Accuracy: 84.54106450080872%
#
# ADAM-N4F1_HiringDecision_tanh > epochs: 217 loss: 0.09890904277563095 val_loss: 0.11371263116598129 Accuracy: 86.5338146686554% val_Accuracy: 82.36715197563171%
#
# ADAM-N4F1_HiringDecision_relu > epochs: 217 loss: 0.10760222375392914 val_loss: 0.13173268735408783 Accuracy: 86.35265827178955% val_Accuracy: 82.6086938381195%
#
# ADAM-N4F2_HiringDecision_tanh > epochs: 239 loss: 0.11132341623306274 val_loss: 0.10397092252969742 Accuracy: 84.84299778938293% val_Accuracy: 85.99033951759338%
#
# ADAM-N4F2_HiringDecision_relu > epochs: 217 loss: 0.11264856904745102 val_loss: 0.11249825358390808 Accuracy: 85.14492511749268% val_Accuracy: 83.57487916946411%
#
# ADAM-N4F3_HiringDecision_tanh > epochs: 187 loss: 0.10275784879922867 val_loss: 0.15734271705150604 Accuracy: 87.31883764266968% val_Accuracy: 80.67632913589478%
#
# ADAM-N4F3_HiringDecision_relu > epochs: 204 loss: 0.11776901036500931 val_loss: 0.17391754686832428 Accuracy: 85.4468584060669% val_Accuracy: 79.22705411911011%
#
# ADAM-N4F4_HiringDecision_tanh > epochs: 268 loss: 0.11136918514966965 val_loss: 0.08025971055030823 Accuracy: 85.26570200920105% val_Accuracy: 89.13043737411499%
#
# ADAM-N4F4_HiringDecision_relu > epochs: 307 loss: 0.11634168773889542 val_loss: 0.0859978199005127 Accuracy: 83.81642699241638% val_Accuracy: 87.43961453437805%
#
# ADAM-N4F5_HiringDecision_tanh > epochs: 344 loss: 0.09590094536542892 val_loss: 0.09697563946247101 Accuracy: 87.19806671142578% val_Accuracy: 86.23188138008118%
#
# ADAM-N4F5_HiringDecision_relu > epochs: 205 loss: 0.11935003846883774 val_loss: 0.12823711335659027 Accuracy: 84.66183543205261% val_Accuracy: 83.09178948402405%
#
# ADAM-N5F1_HiringDecision_tanh > epochs: 408 loss: 0.09442877769470215 val_loss: 0.11003340035676956 Accuracy: 87.80193328857422% val_Accuracy: 84.78260636329651%
#
# ADAM-N5F1_HiringDecision_relu > epochs: 246 loss: 0.1077466830611229 val_loss: 0.12361249327659607 Accuracy: 86.65459156036377% val_Accuracy: 83.57487916946411%
#
# ADAM-N5F2_HiringDecision_tanh > epochs: 291 loss: 0.10795171558856964 val_loss: 0.10416057705879211 Accuracy: 85.74879169464111% val_Accuracy: 85.99033951759338%
#
# ADAM-N5F2_HiringDecision_relu > epochs: 214 loss: 0.11164454370737076 val_loss: 0.10073158144950867 Accuracy: 84.54106450080872% val_Accuracy: 86.71497702598572%
#
# ADAM-N5F3_HiringDecision_tanh > epochs: 405 loss: 0.09508366137742996 val_loss: 0.14470461010932922 Accuracy: 87.56038546562195% val_Accuracy: 80.91787695884705%
#
# ADAM-N5F3_HiringDecision_relu > epochs: 193 loss: 0.1107366606593132 val_loss: 0.16248103976249695 Accuracy: 86.17149591445923% val_Accuracy: 79.22705411911011%
#
# ADAM-N5F4_HiringDecision_tanh > epochs: 236 loss: 0.11070603132247925 val_loss: 0.08245445787906647 Accuracy: 85.26570200920105% val_Accuracy: 89.37197923660278%
#
# ADAM-N5F4_HiringDecision_relu > epochs: 230 loss: 0.11382650583982468 val_loss: 0.08103968948125839 Accuracy: 85.92995405197144% val_Accuracy: 90.09661674499512%
#
# ADAM-N5F5_HiringDecision_tanh > epochs: 271 loss: 0.11271726340055466 val_loss: 0.12546992301940918 Accuracy: 85.56763529777527% val_Accuracy: 83.57487916946411%
#
# ADAM-N5F5_HiringDecision_relu > epochs: 413 loss: 0.10987792164087296 val_loss: 0.12007597088813782 Accuracy: 86.77536249160767% val_Accuracy: 85.99033951759338%

# %%
resultado_resumido = pd.DataFrame()

lista_dict = []
for qtde_neuronio in numpy.arange(1, maximo_neuronios+1):
    for funcao_ativacao in funcoes_ativacao:
        filtrado = df_resultados[(df_resultados['neurons']==qtde_neuronio) & (df_resultados['model_name'].str.contains(funcao_ativacao))]
        temp_dict ={}
        temp_dict['neuronios'] = qtde_neuronio
        temp_dict['ativacao'] = funcao_ativacao
        temp_dict[f'{metrica}_media'] =  filtrado.loc[:, metrica].mean()
        stringVal = f'val_{metrica}'
        temp_dict[f'{stringVal}_media'] =  filtrado.loc[:, stringVal].mean()
        temp_dict[f'epocas_media'] =  filtrado.loc[:, 'epochs'].mean()
        temp_dict[f'val_loss_media'] =  filtrado.loc[:, 'val_loss'].mean()
        temp_dict[f'loss_media'] =  filtrado.loc[:, 'loss'].mean()
        lista_dict.append(temp_dict)
        

resultado_resumido = pd.DataFrame(lista_dict)
resultado_resumido.sort_values(by=f'{metrica}_media', ascending=False)
# Out:
#    neuronios ativacao  Accuracy_media  val_Accuracy_media  epocas_media  \
# 8          5     tanh        0.863889            0.849275         322.2
# 6          4     tanh        0.862319            0.848792         251.0
# 9          5     relu        0.860145            0.851208         259.2
# 7          4     relu        0.850845            0.831884         230.0
# 4          3     tanh        0.848068            0.835266         298.6
# 5          3     relu        0.846498            0.838647         290.0
# 2          2     tanh        0.842995            0.831401         280.8
# 1          1     relu        0.842754            0.831884         398.8
# 0          1     tanh        0.840459            0.837681         277.4
# 3          2     relu        0.839976            0.838164         257.4
#
#    val_loss_media  loss_media
# 8        0.113365    0.104177
# 6        0.110452    0.104052
# 9        0.117588    0.110766
# 7        0.126477    0.114742
# 4        0.122966    0.115300
# 5        0.124284    0.116579
# 2        0.126554    0.118652
# 1        0.133513    0.125094
# 0        0.129594    0.124508
# 3        0.133245    0.125627
